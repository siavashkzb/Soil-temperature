# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Data/df_100.xlsx")
df.head()
# Out:
#    AvgAir_T_TempC  MaxAir_T_TempC  MinAir_T_TempC  Avg_Soil_TP100_TempC  \
# 0           24.24           30.42            0.00                10.860
# 1           22.25           28.47           16.63                 8.150
# 2           20.45           24.77           16.77                 7.739
# 3           20.11           25.32           14.59                 7.795
# 4           23.52           28.47           17.78                 7.982
#
#    Max_Soil_TP100_TempC  Min_Soil_TP100_TempC
# 0                 8.910                 7.823
# 1                 8.910                 7.823
# 2                 7.823                 7.702
# 3                 7.890                 7.717
# 4                 8.080                 7.880

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AvgAir_T_TempC        433 non-null    float64
#  1   MaxAir_T_TempC        433 non-null    float64
#  2   MinAir_T_TempC        433 non-null    float64
#  3   Avg_Soil_TP100_TempC  433 non-null    float64
#  4   Max_Soil_TP100_TempC  433 non-null    float64
#  5   Min_Soil_TP100_TempC  433 non-null    float64
# dtypes: float64(6)
# memory usage: 20.4 KB

# %%
df["Avg_Soil_TP100_TempC_Plus_1"] = df["Avg_Soil_TP100_TempC"].shift(-1)
df["Avg_Soil_TP100_TempC_Plus_2"] = df["Avg_Soil_TP100_TempC"].shift(-2)

df["Max_Soil_TP100_TempC_Plus_1"] = df["Max_Soil_TP100_TempC"].shift(-1)
df["Max_Soil_TP100_TempC_Plus_2"] = df["Max_Soil_TP100_TempC"].shift(-2)

df["Min_Soil_TP100_TempC_Plus_1"] = df["Min_Soil_TP100_TempC"].shift(-1)
df["Min_Soil_TP100_TempC_Plus_2"] = df["Min_Soil_TP100_TempC"].shift(-2)

df["AvgAir_T_TempC_Minus_6"] = df["AvgAir_T_TempC"].shift(6)
df["AvgAir_T_TempC_Minus_5"] = df["AvgAir_T_TempC"].shift(5)
df["AvgAir_T_TempC_Minus_4"] = df["AvgAir_T_TempC"].shift(4)
df["AvgAir_T_TempC_Minus_3"] = df["AvgAir_T_TempC"].shift(3)
df["AvgAir_T_TempC_Minus_2"] = df["AvgAir_T_TempC"].shift(2)
df["AvgAir_T_TempC_Minus_1"] = df["AvgAir_T_TempC"].shift(1)

df["MaxAir_T_TempC_Minus_6"] = df["MaxAir_T_TempC"].shift(6)
df["MaxAir_T_TempC_Minus_5"] = df["MaxAir_T_TempC"].shift(5)
df["MaxAir_T_TempC_Minus_4"] = df["MaxAir_T_TempC"].shift(4)
df["MaxAir_T_TempC_Minus_3"] = df["MaxAir_T_TempC"].shift(3)
df["MaxAir_T_TempC_Minus_2"] = df["MaxAir_T_TempC"].shift(2)
df["MaxAir_T_TempC_Minus_1"] = df["MaxAir_T_TempC"].shift(1)


df["MinAir_T_TempC_Minus_6"] = df["MinAir_T_TempC"].shift(6)
df["MinAir_T_TempC_Minus_5"] = df["MinAir_T_TempC"].shift(5)
df["MinAir_T_TempC_Minus_4"] = df["MinAir_T_TempC"].shift(4)
df["MinAir_T_TempC_Minus_3"] = df["MinAir_T_TempC"].shift(3)
df["MinAir_T_TempC_Minus_2"] = df["MinAir_T_TempC"].shift(2)
df["MinAir_T_TempC_Minus_1"] = df["MinAir_T_TempC"].shift(1)

# %%
df = df[["AvgAir_T_TempC_Minus_6","MaxAir_T_TempC_Minus_6","MinAir_T_TempC_Minus_6",
          "AvgAir_T_TempC_Minus_5","MaxAir_T_TempC_Minus_5","MinAir_T_TempC_Minus_5",
          "AvgAir_T_TempC_Minus_4","MaxAir_T_TempC_Minus_4","MinAir_T_TempC_Minus_4",
          "AvgAir_T_TempC_Minus_3","MaxAir_T_TempC_Minus_3","MinAir_T_TempC_Minus_3",
          "AvgAir_T_TempC_Minus_2","MaxAir_T_TempC_Minus_2","MinAir_T_TempC_Minus_2",
          "AvgAir_T_TempC_Minus_1","MaxAir_T_TempC_Minus_1","MinAir_T_TempC_Minus_1",
          "AvgAir_T_TempC","MaxAir_T_TempC","MinAir_T_TempC",
          "Avg_Soil_TP100_TempC","Max_Soil_TP100_TempC","Min_Soil_TP100_TempC",
          "Avg_Soil_TP100_TempC_Plus_1","Max_Soil_TP100_TempC_Plus_1","Min_Soil_TP100_TempC_Plus_1",
          "Avg_Soil_TP100_TempC_Plus_2","Max_Soil_TP100_TempC_Plus_2","Min_Soil_TP100_TempC_Plus_2"]]
df.dropna(inplace=True)

# %%
df.reset_index(drop="True", inplace=True)

# %%
df
# Out:
#      AvgAir_T_TempC_Minus_6  MaxAir_T_TempC_Minus_6  MinAir_T_TempC_Minus_6  \
# 0                     24.24                   30.42                    0.00
# 1                     22.25                   28.47                   16.63
# 2                     20.45                   24.77                   16.77
# 3                     20.11                   25.32                   14.59
# 4                     23.52                   28.47                   17.78
# ..                      ...                     ...                     ...
# 420                   19.75                   29.30                    9.16
# 421                   18.19                   24.56                   10.54
# 422                   15.45                   24.52                    4.61
# 423                   19.27                   26.70                    9.93
# 424                   16.55                   21.89                   10.94
#
#      AvgAir_T_TempC_Minus_5  MaxAir_T_TempC_Minus_5  MinAir_T_TempC_Minus_5  \
# 0                     22.25                   28.47                   16.63
# 1                     20.45                   24.77                   16.77
# 2                     20.11                   25.32                   14.59
# 3                     23.52                   28.47                   17.78
# 4                     22.08                   27.30                   14.37
# ..                      ...                     ...                     ...
# 420                   18.19                   24.56                   10.54
# 421                   15.45                   24.52                    4.61
# 422                   19.27                   26.70                    9.93
# 423                   16.55                   21.89                   10.94
# 424                   14.50                   20.54                    6.70
#
#      AvgAir_T_TempC_Minus_4  MaxAir_T_TempC_Minus_4  MinAir_T_TempC_Minus_4  \
# 0                     20.45                   24.77                   16.77
# 1                     20.11                   25.32                   14.59
# 2                     23.52                   28.47                   17.78
# 3                     22.08                   27.30                   14.37
# 4                     21.49                   29.56                   11.12
# ..                      ...                     ...                     ...
# 420                   15.45                   24.52                    4.61
# 421                   19.27                   26.70                    9.93
# 422                   16.55                   21.89                   10.94
# 423                   14.50                   20.54                    6.70
# 424                   15.02                   23.63                    5.25
#
#      AvgAir_T_TempC_Minus_3  ...  MinAir_T_TempC  Avg_Soil_TP100_TempC  \
# 0                     20.11  ...           11.12                  8.37
# 1                     23.52  ...           15.37                  8.56
# 2                     22.08  ...           14.90                  8.88
# 3                     21.49  ...           12.12                  9.14
# 4                     21.90  ...           12.12                  9.37
# ..                      ...  ...             ...                   ...
# 420                   19.27  ...            5.25                 13.03
# 421                   16.55  ...            9.71                 12.99
# 422                   14.50  ...           16.47                 12.95
# 423                   15.02  ...           15.88                 12.89
# 424                   18.12  ...           13.83                 12.87
#
#      Max_Soil_TP100_TempC  Min_Soil_TP100_TempC  Avg_Soil_TP100_TempC_Plus_1  \
# 0                    8.47                  8.27                         8.56
# 1                    8.73                  8.46                         8.88
# 2                    9.02                  8.72                         9.14
# 3                    9.26                  9.01                         9.37
# 4                    9.47                  9.25                         9.57
# ..                    ...                   ...                          ...
# 420                 13.05                 13.00                        12.99
# 421                 13.02                 12.96                        12.95
# 422                 12.99                 12.92                        12.89
# 423                 12.92                 12.88                        12.87
# 424                 12.88                 12.86                        12.86
#
#      Max_Soil_TP100_TempC_Plus_1  Min_Soil_TP100_TempC_Plus_1  \
# 0                           8.73                         8.46
# 1                           9.02                         8.72
# 2                           9.26                         9.01
# 3                           9.47                         9.25
# 4                           9.67                         9.47
# ..                           ...                          ...
# 420                        13.02                        12.96
# 421                        12.99                        12.92
# 422                        12.92                        12.88
# 423                        12.88                        12.86
# 424                        12.87                        12.85
#
#      Avg_Soil_TP100_TempC_Plus_2  Max_Soil_TP100_TempC_Plus_2  \
# 0                           8.88                         9.02
# 1                           9.14                         9.26
# 2                           9.37                         9.47
# 3                           9.57                         9.67
# 4                           9.73                         9.81
# ..                           ...                          ...
# 420                        12.95                        12.99
# 421                        12.89                        12.92
# 422                        12.87                        12.88
# 423                        12.86                        12.87
# 424                        12.86                        12.87
#
#      Min_Soil_TP100_TempC_Plus_2
# 0                           8.72
# 1                           9.01
# 2                           9.25
# 3                           9.47
# 4                           9.66
# ..                           ...
# 420                        12.92
# 421                        12.88
# 422                        12.86
# 423                        12.85
# 424                        12.84
#
# [425 rows x 30 columns]

# %% [markdown]
# # 2 - Feature Selection

# %%
# df --> Dataframe
#Ys --> a list of all target variables
#y --> the main target variable - string
def FeatureSelection(df,Ys,y,corr):
    X = df.drop(Ys,axis=1)
    Y = df[y]
    df_final = pd.concat([X,Y],axis=1)
    indexes = df_final.corr()[df_final.corr()[y] > corr].index
    df_final = df_final[indexes]
    return df_final

# %%
Ys = ["Avg_Soil_TP100_TempC", "Max_Soil_TP100_TempC", "Min_Soil_TP100_TempC","Avg_Soil_TP100_TempC_Plus_1",
     "Max_Soil_TP100_TempC_Plus_1","Min_Soil_TP100_TempC_Plus_1", "Avg_Soil_TP100_TempC_Plus_2", 
      "Max_Soil_TP100_TempC_Plus_2", "Min_Soil_TP100_TempC_Plus_2"]

# %%
df_avg = FeatureSelection(df,Ys,y = "Avg_Soil_TP100_TempC",corr=0.5)
df_max = FeatureSelection(df,Ys,y = "Max_Soil_TP100_TempC",corr=0.5)
df_min = FeatureSelection(df,Ys,y = "Min_Soil_TP100_TempC",corr=0.5)
df_avg_plus1 = FeatureSelection(df,Ys,y = "Avg_Soil_TP100_TempC_Plus_1",corr=0.5)
df_max_plus1 = FeatureSelection(df,Ys,y = "Max_Soil_TP100_TempC_Plus_1",corr=0.5)
df_min_plus1 = FeatureSelection(df,Ys,y = "Min_Soil_TP100_TempC_Plus_1",corr=0.5)
df_avg_plus2 = FeatureSelection(df,Ys,y = "Avg_Soil_TP100_TempC_Plus_2",corr=0.5)
df_max_plus2 = FeatureSelection(df,Ys,y = "Max_Soil_TP100_TempC_Plus_2",corr=0.5)
df_min_plus2 = FeatureSelection(df,Ys,y = "Min_Soil_TP100_TempC_Plus_2",corr=0.5)

# %%
final_result_table_100cm_without_wavelet = pd.DataFrame(columns=["output_variable", "MLAlgo", "real_value", 
                                                               "predicted_value", "mse_list", "mae_list", "r_sqaured"])
final_result_table_100cm_without_wavelet
# Out:
# Empty DataFrame
# Columns: [output_variable, MLAlgo, real_value, predicted_value, mse_list, mae_list, r_sqaured]
# Index: []

# %% [markdown]
# # 3 - SVR Support vector machines for regression Problem

# %% [markdown]
# ### Train test split and data transform

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#df: data frame
#y: target variable --> string
def SplitTransform(df,y,test_size, scaler):
    X = df.drop(y,axis=1).values
    y = df[y].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=101)
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    data = [X_train, X_test,y_train,y_test]
    return data

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
model = SVR(gamma="auto")

# %%
param_grid = {"kernel" : ["rbf"],
             "C" : [20]}
grid = GridSearchCV(model,param_grid, cv = 5)

# %%
Ys = {"Avg_Soil_TP100_TempC":df_avg, "Max_Soil_TP100_TempC":df_max, "Min_Soil_TP100_TempC":df_min,"Avg_Soil_TP100_TempC_Plus_1":df_avg_plus1,
     "Max_Soil_TP100_TempC_Plus_1":df_max_plus1,"Min_Soil_TP100_TempC_Plus_1":df_min_plus1, "Avg_Soil_TP100_TempC_Plus_2":df_avg_plus2, 
      "Max_Soil_TP100_TempC_Plus_2":df_max_plus2, "Min_Soil_TP100_TempC_Plus_2":df_min_plus2}

# %%
SVM_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    SVM_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["SVM" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_100cm_without_wavelet = pd.concat([final_result_table_100cm_without_wavelet,result])
# Out:
# Avg_Soil_TP100_TempC
# Max_Soil_TP100_TempC
# Min_Soil_TP100_TempC
# Avg_Soil_TP100_TempC_Plus_1
# Max_Soil_TP100_TempC_Plus_1
# Min_Soil_TP100_TempC_Plus_1
# Avg_Soil_TP100_TempC_Plus_2
# Max_Soil_TP100_TempC_Plus_2
# Min_Soil_TP100_TempC_Plus_2

# %%
final_result_table_100cm_without_wavelet
# Out:
#                  output_variable MLAlgo  real_value  predicted_value  \
# 0           Avg_Soil_TP100_TempC    SVM       4.998         2.836700
# 1           Avg_Soil_TP100_TempC    SVM       5.724         2.865241
# 2           Avg_Soil_TP100_TempC    SVM       0.866         2.371794
# 3           Avg_Soil_TP100_TempC    SVM       7.172        12.430638
# 4           Avg_Soil_TP100_TempC    SVM      12.710        12.294876
# ..                           ...    ...         ...              ...
# 123  Min_Soil_TP100_TempC_Plus_2    SVM       0.821         3.737089
# 124  Min_Soil_TP100_TempC_Plus_2    SVM      10.900        11.589461
# 125  Min_Soil_TP100_TempC_Plus_2    SVM       1.429         1.409889
# 126  Min_Soil_TP100_TempC_Plus_2    SVM       1.242         0.421965
# 127  Min_Soil_TP100_TempC_Plus_2    SVM       4.728         3.795380
#
#       mse_list  mae_list  r_sqaured
# 0    13.109335  2.725901   0.407301
# 1    13.109335  2.725901   0.407301
# 2    13.109335  2.725901   0.407301
# 3    13.109335  2.725901   0.407301
# 4    13.109335  2.725901   0.407301
# ..         ...       ...        ...
# 123  12.018403  2.612625   0.459336
# 124  12.018403  2.612625   0.459336
# 125  12.018403  2.612625   0.459336
# 126  12.018403  2.612625   0.459336
# 127  12.018403  2.612625   0.459336
#
# [1152 rows x 7 columns]

# %% [markdown]
# # 4 - XGBoost (Extreme Gradient Boosting Method) for regression problem

# %% [markdown]
# ### Building the model

# %%
import xgboost as xg

# %%
model = xg.XGBRegressor(objective ='reg:squarederror')

# %%
param_grid = {
    'max_depth': [4],
    'learning_rate': [0.05],
    'gamma': [0.25],
    'reg_lambda': [1.0],
    'n_estimators' : [100]
      }
grid = GridSearchCV(model,param_grid, cv = 5, verbose=3)

# %%
XGBoost_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    XGBoost_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["XGBoost" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_100cm_without_wavelet = pd.concat([final_result_table_100cm_without_wavelet,result])
# Out:
# Avg_Soil_TP100_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.552, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.685, total=   0.1s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.511, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.677, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.608, total=   0.1s
# Max_Soil_TP100_TempC
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.547, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.671, total=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.520, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.650, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.596, total=   0.1s
# Min_Soil_TP100_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.542, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.670, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.535, total=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.657, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.586, total=   0.1s
# Avg_Soil_TP100_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.541, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.691, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.533, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.662, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.628, total=   0.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Max_Soil_TP100_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.557, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.684, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.552, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.667, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.612, total=   0.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Min_Soil_TP100_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.560, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.691, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.527, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.674, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.617, total=   0.1s
# Avg_Soil_TP100_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.547, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.705, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.572, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.698, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.643, total=   0.1s
# Max_Soil_TP100_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.556, total=   0.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.705, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.565, total=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.679, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.642, total=   0.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Min_Soil_TP100_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.556, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.706, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.555, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.694, total=   0.1s
# [CV] gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0
# [CV]  gamma=0.25, learning_rate=0.05, max_depth=4, n_estimators=100, reg_lambda=1.0, score=0.642, total=   0.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished

# %%
final_result_table_100cm_without_wavelet
# Out:
#                  output_variable   MLAlgo  real_value  predicted_value  \
# 0           Avg_Soil_TP100_TempC      SVM       4.998         2.836700
# 1           Avg_Soil_TP100_TempC      SVM       5.724         2.865241
# 2           Avg_Soil_TP100_TempC      SVM       0.866         2.371794
# 3           Avg_Soil_TP100_TempC      SVM       7.172        12.430638
# 4           Avg_Soil_TP100_TempC      SVM      12.710        12.294876
# ..                           ...      ...         ...              ...
# 123  Min_Soil_TP100_TempC_Plus_2  XGBoost       0.821         7.315916
# 124  Min_Soil_TP100_TempC_Plus_2  XGBoost      10.900         9.989389
# 125  Min_Soil_TP100_TempC_Plus_2  XGBoost       1.429         1.664700
# 126  Min_Soil_TP100_TempC_Plus_2  XGBoost       1.242         0.801838
# 127  Min_Soil_TP100_TempC_Plus_2  XGBoost       4.728         4.288347
#
#       mse_list  mae_list  r_sqaured
# 0    13.109335  2.725901   0.407301
# 1    13.109335  2.725901   0.407301
# 2    13.109335  2.725901   0.407301
# 3    13.109335  2.725901   0.407301
# 4    13.109335  2.725901   0.407301
# ..         ...       ...        ...
# 123  11.638705  2.577353   0.476418
# 124  11.638705  2.577353   0.476418
# 125  11.638705  2.577353   0.476418
# 126  11.638705  2.577353   0.476418
# 127  11.638705  2.577353   0.476418
#
# [2304 rows x 7 columns]

# %% [markdown]
# # 5 - ANN

# %% [markdown]
# ### Building the Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor

# %%
def create_model(neurons,hidden_layers, optimizer, activation):
    model = Sequential()
    
    # Add aninput layer
    model.add(Dense(X_train.shape[1], activation = activation))
    
    for i in range(hidden_layers):
    # Add one hidden layer
        model.add(Dense(neurons, activation=activation))
        
        
    # Add an output layer 
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer = optimizer, loss="mse")
    
    return model

# %%
model = KerasRegressor(build_fn=create_model, verbose = 3)

# %%
param_grid = {
    'batch_size': [128],
    'epochs': [400],
    'neurons': [150],
    'hidden_layers': [6],
    'optimizer' : ['Adam'],
    "activation" : ["sigmoid"]
      }
grid = GridSearchCV(model,param_grid,n_jobs=-1, verbose=3)

# %%
ANN_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    ANN_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["ANN" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_100cm_without_wavelet = pd.concat([final_result_table_100cm_without_wavelet,result])
# Out:
# Avg_Soil_TP100_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   23.9s remaining:   35.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   29.9s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Max_Soil_TP100_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   12.9s remaining:   19.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   16.9s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Min_Soil_TP100_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   11.1s remaining:   16.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   15.0s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Avg_Soil_TP100_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.4s remaining:   15.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.6s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Max_Soil_TP100_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.7s remaining:   16.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.9s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x000001977A408940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001977A408700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Min_Soil_TP100_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.6s remaining:   15.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.7s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x000001977711F700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001977A1415E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Avg_Soil_TP100_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.7s remaining:   16.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   15.0s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x00000197775CC1F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001977751DAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Max_Soil_TP100_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.6s remaining:   16.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.8s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x000001977A24D310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019778CEE0D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Min_Soil_TP100_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.7s remaining:   16.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.8s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x000001977751DDC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001977A141310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
final_result_table_100cm_without_wavelet.reset_index(drop = True)
# Out:
#                   output_variable MLAlgo  real_value  predicted_value  \
# 0            Avg_Soil_TP100_TempC    SVM       4.998         2.836700
# 1            Avg_Soil_TP100_TempC    SVM       5.724         2.865241
# 2            Avg_Soil_TP100_TempC    SVM       0.866         2.371794
# 3            Avg_Soil_TP100_TempC    SVM       7.172        12.430638
# 4            Avg_Soil_TP100_TempC    SVM      12.710        12.294876
# ...                           ...    ...         ...              ...
# 3451  Min_Soil_TP100_TempC_Plus_2    ANN       0.821         3.221498
# 3452  Min_Soil_TP100_TempC_Plus_2    ANN      10.900        11.559916
# 3453  Min_Soil_TP100_TempC_Plus_2    ANN       1.429         3.223148
# 3454  Min_Soil_TP100_TempC_Plus_2    ANN       1.242         3.223147
# 3455  Min_Soil_TP100_TempC_Plus_2    ANN       4.728         3.223134
#
#        mse_list  mae_list  r_sqaured
# 0     13.109335  2.725901   0.407301
# 1     13.109335  2.725901   0.407301
# 2     13.109335  2.725901   0.407301
# 3     13.109335  2.725901   0.407301
# 4     13.109335  2.725901   0.407301
# ...         ...       ...        ...
# 3451  10.810284  2.518594 -10.810284
# 3452  10.810284  2.518594 -10.810284
# 3453  10.810284  2.518594 -10.810284
# 3454  10.810284  2.518594 -10.810284
# 3455  10.810284  2.518594 -10.810284
#
# [3456 rows x 7 columns]

# %%
final_result_table_100cm_without_wavelet.to_csv(r'C:\Users\siava\OneDrive - University of Manitoba\D\Computer science\Data Science Projects\Soil-temperature\Results\100 cm\final_result_table_100cm_without_wavelet.csv'
                                             ,index=False)
