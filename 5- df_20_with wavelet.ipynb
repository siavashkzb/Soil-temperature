# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pywt

# %%
df = pd.read_excel("Data/df_20.xlsx")
df.head()
# Out:
#    AvgAir_T_TempC  MaxAir_T_TempC  MinAir_T_TempC  Avg_Soil_TP20_TempC  \
# 0            8.16           11.96            1.40                8.530
# 1            5.48            7.33            3.47                7.926
# 2            6.41            9.25            1.81                8.130
# 3            9.17           10.67            5.04                8.790
# 4            3.38            5.71           -0.33                8.590
#
#    Max_Soil_TP20_TempC  Min_Soil_TP20_TempC
# 0                 8.85                8.230
# 1                 8.28                7.774
# 2                 8.47                7.927
# 3                 9.15                8.440
# 4                 9.09                8.280

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AvgAir_T_TempC       1038 non-null   float64
#  1   MaxAir_T_TempC       1038 non-null   float64
#  2   MinAir_T_TempC       1038 non-null   float64
#  3   Avg_Soil_TP20_TempC  1038 non-null   float64
#  4   Max_Soil_TP20_TempC  1038 non-null   float64
#  5   Min_Soil_TP20_TempC  1038 non-null   float64
# dtypes: float64(6)
# memory usage: 48.8 KB

# %%
df["Avg_Soil_TP20_TempC_Plus_1"] = df["Avg_Soil_TP20_TempC"].shift(-1)
df["Avg_Soil_TP20_TempC_Plus_2"] = df["Avg_Soil_TP20_TempC"].shift(-2)

df["Max_Soil_TP20_TempC_Plus_1"] = df["Max_Soil_TP20_TempC"].shift(-1)
df["Max_Soil_TP20_TempC_Plus_2"] = df["Max_Soil_TP20_TempC"].shift(-2)

df["Min_Soil_TP20_TempC_Plus_1"] = df["Min_Soil_TP20_TempC"].shift(-1)
df["Min_Soil_TP20_TempC_Plus_2"] = df["Min_Soil_TP20_TempC"].shift(-2)

df["AvgAir_T_TempC_Minus_6"] = df["AvgAir_T_TempC"].shift(6)
df["AvgAir_T_TempC_Minus_5"] = df["AvgAir_T_TempC"].shift(5)
df["AvgAir_T_TempC_Minus_4"] = df["AvgAir_T_TempC"].shift(4)
df["AvgAir_T_TempC_Minus_3"] = df["AvgAir_T_TempC"].shift(3)
df["AvgAir_T_TempC_Minus_2"] = df["AvgAir_T_TempC"].shift(2)
df["AvgAir_T_TempC_Minus_1"] = df["AvgAir_T_TempC"].shift(1)

df["MaxAir_T_TempC_Minus_6"] = df["MaxAir_T_TempC"].shift(6)
df["MaxAir_T_TempC_Minus_5"] = df["MaxAir_T_TempC"].shift(5)
df["MaxAir_T_TempC_Minus_4"] = df["MaxAir_T_TempC"].shift(4)
df["MaxAir_T_TempC_Minus_3"] = df["MaxAir_T_TempC"].shift(3)
df["MaxAir_T_TempC_Minus_2"] = df["MaxAir_T_TempC"].shift(2)
df["MaxAir_T_TempC_Minus_1"] = df["MaxAir_T_TempC"].shift(1)


df["MinAir_T_TempC_Minus_6"] = df["MinAir_T_TempC"].shift(6)
df["MinAir_T_TempC_Minus_5"] = df["MinAir_T_TempC"].shift(5)
df["MinAir_T_TempC_Minus_4"] = df["MinAir_T_TempC"].shift(4)
df["MinAir_T_TempC_Minus_3"] = df["MinAir_T_TempC"].shift(3)
df["MinAir_T_TempC_Minus_2"] = df["MinAir_T_TempC"].shift(2)
df["MinAir_T_TempC_Minus_1"] = df["MinAir_T_TempC"].shift(1)

# %%
df = df[["AvgAir_T_TempC_Minus_6","MaxAir_T_TempC_Minus_6","MinAir_T_TempC_Minus_6",
          "AvgAir_T_TempC_Minus_5","MaxAir_T_TempC_Minus_5","MinAir_T_TempC_Minus_5",
          "AvgAir_T_TempC_Minus_4","MaxAir_T_TempC_Minus_4","MinAir_T_TempC_Minus_4",
          "AvgAir_T_TempC_Minus_3","MaxAir_T_TempC_Minus_3","MinAir_T_TempC_Minus_3",
          "AvgAir_T_TempC_Minus_2","MaxAir_T_TempC_Minus_2","MinAir_T_TempC_Minus_2",
          "AvgAir_T_TempC_Minus_1","MaxAir_T_TempC_Minus_1","MinAir_T_TempC_Minus_1",
          "AvgAir_T_TempC","MaxAir_T_TempC","MinAir_T_TempC",
          "Avg_Soil_TP20_TempC","Max_Soil_TP20_TempC","Min_Soil_TP20_TempC",
          "Avg_Soil_TP20_TempC_Plus_1","Max_Soil_TP20_TempC_Plus_1","Min_Soil_TP20_TempC_Plus_1",
          "Avg_Soil_TP20_TempC_Plus_2","Max_Soil_TP20_TempC_Plus_2","Min_Soil_TP20_TempC_Plus_2"]]
df.dropna(inplace=True)

# %%
df.reset_index(drop="True", inplace=True)

# %%
def WaveletTransform(x,walvelettype,level):
    
    size = np.shape(x)
    length = (size[0] // (2**level)) * (2 ** level)
    x = x.iloc[0:length]
    bigmats = []
    for i in x.columns:
        vec = x[i].values
        cAs_cDs = pywt.swt(vec, wavelet=walvelettype, level=level,axis=0) 
        for j in cAs_cDs:
            bigmats.append(j[0])
            bigmats.append(j[1])

    
    features_num = len(bigmats)
    x = np.zeros((length, features_num))
    for i in range(0 ,len(bigmats)):
        for j in range(0,len(bigmats[0])):
            x[j,i] = x[j,i] + bigmats[i][j]
    
    return(x)

# %%
x = df.drop(["Avg_Soil_TP20_TempC","Max_Soil_TP20_TempC","Min_Soil_TP20_TempC",
            "Avg_Soil_TP20_TempC_Plus_1","Max_Soil_TP20_TempC_Plus_1","Min_Soil_TP20_TempC_Plus_1",
            "Avg_Soil_TP20_TempC_Plus_2","Max_Soil_TP20_TempC_Plus_2","Min_Soil_TP20_TempC_Plus_2"],axis=1)

# %%
y = df[["Avg_Soil_TP20_TempC","Max_Soil_TP20_TempC","Min_Soil_TP20_TempC",
            "Avg_Soil_TP20_TempC_Plus_1","Max_Soil_TP20_TempC_Plus_1","Min_Soil_TP20_TempC_Plus_1",
            "Avg_Soil_TP20_TempC_Plus_2","Max_Soil_TP20_TempC_Plus_2","Min_Soil_TP20_TempC_Plus_2"]].values

# %%
x = WaveletTransform(x,"db5",5)

# %%
x.shape
# Out:
# (1024, 210)

# %%
y = df[0:x.shape[0]]

# %%
x = pd.DataFrame(x)

# %%
df = pd.concat([x,y],axis=1)

# %%
df
# Out:
#               0          1          2          3          4         5  \
# 0     68.521901  17.125962  80.918016  18.499315  57.324270  1.505259
# 1     69.864985  19.036618  80.356873  17.770988  58.293480  4.936171
# 2     71.233887  20.658360  79.803331  15.821483  59.116780  8.517321
# 3     72.628403  22.015623  79.333324  13.158899  59.729453  9.575284
# 4     74.037831  22.870567  78.953846   9.902946  60.200359  7.423347
# ...         ...        ...        ...        ...        ...       ...
# 1019  61.923002   4.258578  81.131265   3.279522  54.658989 -1.836325
# 1020  63.275745   6.961267  81.494441   8.033681  54.776647 -0.704872
# 1021  64.585938   9.813100  81.679043  12.469320  55.021807 -0.797959
# 1022  65.881449  12.519510  81.644177  15.966304  55.480309 -1.446066
# 1023  67.193146  14.934549  81.379328  17.926804  56.298706 -0.873256
#
#               6         7          8         9  ...  MinAir_T_TempC  \
# 0     35.943367  0.287648  26.367510 -4.310982  ...            4.16
# 1     35.485424  1.596280  25.789807  0.923497  ...            2.22
# 2     36.649358 -1.295042  17.930719  2.165125  ...            0.77
# 3     38.144801 -4.192752  10.285471 -0.609532  ...           -0.23
# 4     38.420068 -1.774528   9.935624 -1.422230  ...           -0.03
# ...         ...       ...        ...       ...  ...             ...
# 1019  48.413367 -7.408064  23.874455  0.530526  ...            9.16
# 1020  48.225825 -1.071688  24.252076 -3.412353  ...           10.54
# 1021  45.817422  5.591794  25.947943  1.267339  ...            4.61
# 1022  41.990818  3.298393  25.132408  1.920876  ...            9.93
# 1023  38.315728 -0.826228  24.241695  1.343282  ...           10.94
#
#       Avg_Soil_TP20_TempC  Max_Soil_TP20_TempC  Min_Soil_TP20_TempC  \
# 0                   7.685                7.827                7.598
# 1                  10.930               25.420                7.666
# 2                   7.693                8.630                7.440
# 3                   7.224                7.451                6.960
# 4                   7.327                7.898                6.849
# ...                   ...                  ...                  ...
# 1019               15.620               15.960               15.340
# 1020               15.880               15.980               15.750
# 1021               15.230               15.900               14.880
# 1022               15.010               15.300               14.800
# 1023               15.100               15.330               14.910
#
#       Avg_Soil_TP20_TempC_Plus_1  Max_Soil_TP20_TempC_Plus_1  \
# 0                         10.930                      25.420
# 1                          7.693                       8.630
# 2                          7.224                       7.451
# 3                          7.327                       7.898
# 4                          7.777                       8.470
# ...                          ...                         ...
# 1019                      15.880                      15.980
# 1020                      15.230                      15.900
# 1021                      15.010                      15.300
# 1022                      15.100                      15.330
# 1023                      14.730                      15.210
#
#       Min_Soil_TP20_TempC_Plus_1  Avg_Soil_TP20_TempC_Plus_2  \
# 0                          7.666                       7.693
# 1                          7.440                       7.224
# 2                          6.960                       7.327
# 3                          6.849                       7.777
# 4                          7.312                       8.610
# ...                          ...                         ...
# 1019                      15.750                      15.230
# 1020                      14.880                      15.010
# 1021                      14.800                      15.100
# 1022                      14.910                      14.730
# 1023                      14.480                      14.350
#
#       Max_Soil_TP20_TempC_Plus_2  Min_Soil_TP20_TempC_Plus_2
# 0                          8.630                       7.440
# 1                          7.451                       6.960
# 2                          7.898                       6.849
# 3                          8.470                       7.312
# 4                          9.310                       8.280
# ...                          ...                         ...
# 1019                      15.900                      14.880
# 1020                      15.300                      14.800
# 1021                      15.330                      14.910
# 1022                      15.210                      14.480
# 1023                      14.680                      14.040
#
# [1024 rows x 240 columns]

# %% [markdown]
# # 2 - Feature Selection

# %%
#df --> Dataframe
#Ys --> a list of all target variables
#y --> the main target variable - string
def FeatureSelection(df,Ys,y,corr):
    X = df.drop(Ys,axis=1)
    Y = df[y]
    df_final = pd.concat([X,Y],axis=1)
    indexes = df_final.corr()[df_final.corr()[y] > corr].index
    df_final = df_final[indexes]
    return df_final

# %%
Ys = ["Avg_Soil_TP20_TempC", "Max_Soil_TP20_TempC", "Min_Soil_TP20_TempC","Avg_Soil_TP20_TempC_Plus_1",
     "Max_Soil_TP20_TempC_Plus_1","Min_Soil_TP20_TempC_Plus_1", "Avg_Soil_TP20_TempC_Plus_2", 
      "Max_Soil_TP20_TempC_Plus_2", "Min_Soil_TP20_TempC_Plus_2"]

# %%
df_avg = FeatureSelection(df,Ys,y = "Avg_Soil_TP20_TempC",corr=0.5)
df_max = FeatureSelection(df,Ys,y = "Max_Soil_TP20_TempC",corr=0.5)
df_min = FeatureSelection(df,Ys,y = "Min_Soil_TP20_TempC",corr=0.5)
df_avg_plus1 = FeatureSelection(df,Ys,y = "Avg_Soil_TP20_TempC_Plus_1",corr=0.5)
df_max_plus1 = FeatureSelection(df,Ys,y = "Max_Soil_TP20_TempC_Plus_1",corr=0.5)
df_min_plus1 = FeatureSelection(df,Ys,y = "Min_Soil_TP20_TempC_Plus_1",corr=0.5)
df_avg_plus2 = FeatureSelection(df,Ys,y = "Avg_Soil_TP20_TempC_Plus_2",corr=0.5)
df_max_plus2 = FeatureSelection(df,Ys,y = "Max_Soil_TP20_TempC_Plus_2",corr=0.5)
df_min_plus2 = FeatureSelection(df,Ys,y = "Min_Soil_TP20_TempC_Plus_2",corr=0.5)

# %%
final_result_table_20cm_with_wavelet = pd.DataFrame(columns=["output_variable", "MLAlgo", "real_value", 
                                                               "predicted_value", "mse_list", "mae_list", "r_sqaured"])
final_result_table_20cm_with_wavelet
# Out:
# Empty DataFrame
# Columns: [output_variable, MLAlgo, real_value, predicted_value, mse_list, mae_list, r_sqaured]
# Index: []

# %% [markdown]
# # 3 - SVR Support vector machines for regression Problem

# %% [markdown]
# ### Train test split and data transform

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#df: data frame
#y: target variable --> string
def SplitTransform(df,y,test_size, scaler):
    X = df.drop(y,axis=1).values
    y = df[y].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=101)
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    data = [X_train, X_test,y_train,y_test]
    return data

# %% [markdown]
# ### Building the Model

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
model = SVR(gamma="auto")

# %%
param_grid = {"kernel" : ["rbf"],
             "C" : [40]}
grid = GridSearchCV(model,param_grid, cv = 5)

# %%
Ys = {"Avg_Soil_TP20_TempC":df_avg, "Max_Soil_TP20_TempC":df_max, "Min_Soil_TP20_TempC":df_min,"Avg_Soil_TP20_TempC_Plus_1":df_avg_plus1,
     "Max_Soil_TP20_TempC_Plus_1":df_max_plus1,"Min_Soil_TP20_TempC_Plus_1":df_min_plus1, "Avg_Soil_TP20_TempC_Plus_2":df_avg_plus2, 
      "Max_Soil_TP20_TempC_Plus_2":df_max_plus2, "Min_Soil_TP20_TempC_Plus_2":df_min_plus2}

# %%
SVM_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    SVM_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["WSVM" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_20cm_with_wavelet = pd.concat([final_result_table_20cm_with_wavelet,result])
# Out:
# Avg_Soil_TP20_TempC
# Max_Soil_TP20_TempC
# Min_Soil_TP20_TempC
# Avg_Soil_TP20_TempC_Plus_1
# Max_Soil_TP20_TempC_Plus_1
# Min_Soil_TP20_TempC_Plus_1
# Avg_Soil_TP20_TempC_Plus_2
# Max_Soil_TP20_TempC_Plus_2
# Min_Soil_TP20_TempC_Plus_2

# %%
final_result_table_20cm_with_wavelet
# Out:
#                 output_variable MLAlgo  real_value  predicted_value  mse_list  \
# 0           Avg_Soil_TP20_TempC   WSVM      16.000        18.220685  2.756738
# 1           Avg_Soil_TP20_TempC   WSVM       1.584         1.182354  2.756738
# 2           Avg_Soil_TP20_TempC   WSVM       3.943         4.354686  2.756738
# 3           Avg_Soil_TP20_TempC   WSVM      17.860        18.408924  2.756738
# 4           Avg_Soil_TP20_TempC   WSVM      17.730        18.285324  2.756738
# ..                          ...    ...         ...              ...       ...
# 303  Min_Soil_TP20_TempC_Plus_2   WSVM       3.036         3.168757  2.776576
# 304  Min_Soil_TP20_TempC_Plus_2   WSVM      -1.919        -1.441751  2.776576
# 305  Min_Soil_TP20_TempC_Plus_2   WSVM      15.720        15.872289  2.776576
# 306  Min_Soil_TP20_TempC_Plus_2   WSVM       1.231         1.222870  2.776576
# 307  Min_Soil_TP20_TempC_Plus_2   WSVM      17.280        15.664054  2.776576
#
#      mae_list  r_sqaured
# 0    0.917428   0.960634
# 1    0.917428   0.960634
# 2    0.917428   0.960634
# 3    0.917428   0.960634
# 4    0.917428   0.960634
# ..        ...        ...
# 303  1.000744   0.958101
# 304  1.000744   0.958101
# 305  1.000744   0.958101
# 306  1.000744   0.958101
# 307  1.000744   0.958101
#
# [2772 rows x 7 columns]

# %% [markdown]
# # 4 - XGBoost (Extreme Gradient Boosting Method) for regression problem

# %% [markdown]
# ### Building the model

# %%
import xgboost as xg

# %%
model = xg.XGBRegressor(objective ='reg:squarederror')

# %% [markdown]
# ### Avg_Soil_TP20_TempC

# %%
param_grid = {
    'max_depth': [7],
    'learning_rate': [0.05],
    'gamma': [0],
    'reg_lambda': [1.0],
    'n_estimators' : [150]
      }
grid = GridSearchCV(model,param_grid, cv = 5, verbose=3)

# %%
XGBoost_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    XGBoost_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["WXGBoost" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_20cm_with_wavelet = pd.concat([final_result_table_20cm_with_wavelet,result])
# Out:
# Avg_Soil_TP20_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.970, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.963, total=   1.2s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.2s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.952, total=   1.3s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.970, total=   1.1s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.967, total=   1.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.6s finished
# Max_Soil_TP20_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.971, total=   1.2s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.962, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.939, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.952, total=   1.1s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.969, total=   1.3s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.2s finished
# Min_Soil_TP20_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.977, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.967, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.7s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.960, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.970, total=   1.2s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.969, total=   0.9s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.7s finished
# Avg_Soil_TP20_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.974, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.970, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.7s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.961, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.960, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.968, total=   1.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.8s finished
# Max_Soil_TP20_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.973, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.968, total=   1.2s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.2s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.950, total=   1.2s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.960, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.970, total=   0.9s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.2s finished
# Min_Soil_TP20_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.979, total=   1.2s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.966, total=   1.1s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.959, total=   1.3s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.958, total=   1.3s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.978, total=   1.2s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.9s finished
# Avg_Soil_TP20_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.973, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.954, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.974, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.950, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.968, total=   0.9s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.7s finished
# Max_Soil_TP20_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.972, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.954, total=   1.1s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.971, total=   1.6s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.955, total=   1.3s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.965, total=   1.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.5s finished
# Min_Soil_TP20_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.976, total=   1.3s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.958, total=   2.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.963, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.960, total=   1.0s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.961, total=   1.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.2s finished

# %%
final_result_table_20cm_with_wavelet
# Out:
#                 output_variable    MLAlgo  real_value  predicted_value  \
# 0           Avg_Soil_TP20_TempC      WSVM      16.000        18.220685
# 1           Avg_Soil_TP20_TempC      WSVM       1.584         1.182354
# 2           Avg_Soil_TP20_TempC      WSVM       3.943         4.354686
# 3           Avg_Soil_TP20_TempC      WSVM      17.860        18.408924
# 4           Avg_Soil_TP20_TempC      WSVM      17.730        18.285324
# ..                          ...       ...         ...              ...
# 303  Min_Soil_TP20_TempC_Plus_2  WXGBoost       3.036         3.173856
# 304  Min_Soil_TP20_TempC_Plus_2  WXGBoost      -1.919        -1.697743
# 305  Min_Soil_TP20_TempC_Plus_2  WXGBoost      15.720        15.976201
# 306  Min_Soil_TP20_TempC_Plus_2  WXGBoost       1.231         0.870664
# 307  Min_Soil_TP20_TempC_Plus_2  WXGBoost      17.280        16.309601
#
#      mse_list  mae_list  r_sqaured
# 0    2.756738  0.917428   0.960634
# 1    2.756738  0.917428   0.960634
# 2    2.756738  0.917428   0.960634
# 3    2.756738  0.917428   0.960634
# 4    2.756738  0.917428   0.960634
# ..        ...       ...        ...
# 303  2.408562  0.995251   0.963655
# 304  2.408562  0.995251   0.963655
# 305  2.408562  0.995251   0.963655
# 306  2.408562  0.995251   0.963655
# 307  2.408562  0.995251   0.963655
#
# [5544 rows x 7 columns]

# %% [markdown]
# # 5 - ANN

# %% [markdown]
# ### Building the Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor

# %%
def create_model(neurons,hidden_layers, optimizer, activation):
    model = Sequential()
    
    # Add aninput layer
    model.add(Dense(X_train.shape[1], activation = activation))
    
    for i in range(hidden_layers):
    # Add one hidden layer
        model.add(Dense(neurons, activation=activation))
        
        
    # Add an output layer 
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer = optimizer, loss="mse")
    
    return model

# %%
model = KerasRegressor(build_fn=create_model, verbose = 3)

# %%
param_grid = {
    'batch_size': [128],
    'epochs': [400],
    'neurons': [350],
    'hidden_layers': [4],
    'optimizer' : ['Adam'],
    "activation" : ["relu"]
      }
grid = GridSearchCV(model,param_grid,n_jobs=-1, verbose=3)

# %%
ANN_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    ANN_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["WANN" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_20cm_with_wavelet = pd.concat([final_result_table_20cm_with_wavelet,result])
# Out:
# Avg_Soil_TP20_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.0min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.3min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Max_Soil_TP20_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   52.9s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.1min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Min_Soil_TP20_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   53.1s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.1min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Avg_Soil_TP20_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   52.6s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.2min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Max_Soil_TP20_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   55.5s remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.2min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001A084AF1CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A084B2C940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Min_Soil_TP20_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   53.1s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.1min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001A0FFBAB700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A0FFB74430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Avg_Soil_TP20_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   52.8s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.1min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001A084AF14C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A0836BD310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Max_Soil_TP20_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   53.2s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.1min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001A0822E80D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A085EFDB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Min_Soil_TP20_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   55.2s remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.2min finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001A0FFC27790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A0FF2EC9D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
final_result_table_20cm_with_wavelet.reset_index(drop = True)
# Out:
#                  output_variable MLAlgo  real_value  predicted_value  \
# 0            Avg_Soil_TP20_TempC   WSVM      16.000        18.220685
# 1            Avg_Soil_TP20_TempC   WSVM       1.584         1.182354
# 2            Avg_Soil_TP20_TempC   WSVM       3.943         4.354686
# 3            Avg_Soil_TP20_TempC   WSVM      17.860        18.408924
# 4            Avg_Soil_TP20_TempC   WSVM      17.730        18.285324
# ...                          ...    ...         ...              ...
# 8311  Min_Soil_TP20_TempC_Plus_2   WANN       3.036         2.832552
# 8312  Min_Soil_TP20_TempC_Plus_2   WANN      -1.919        -2.005092
# 8313  Min_Soil_TP20_TempC_Plus_2   WANN      15.720        15.525714
# 8314  Min_Soil_TP20_TempC_Plus_2   WANN       1.231         0.983206
# 8315  Min_Soil_TP20_TempC_Plus_2   WANN      17.280        14.552552
#
#       mse_list  mae_list  r_sqaured
# 0     2.756738  0.917428   0.960634
# 1     2.756738  0.917428   0.960634
# 2     2.756738  0.917428   0.960634
# 3     2.756738  0.917428   0.960634
# 4     2.756738  0.917428   0.960634
# ...        ...       ...        ...
# 8311  1.651378  0.831037  -1.651378
# 8312  1.651378  0.831037  -1.651378
# 8313  1.651378  0.831037  -1.651378
# 8314  1.651378  0.831037  -1.651378
# 8315  1.651378  0.831037  -1.651378
#
# [8316 rows x 7 columns]

# %%
final_result_table_20cm_with_wavelet.to_csv(r'C:\Users\siava\OneDrive - University of Manitoba\D\Computer science\Data Science Projects\Soil-temperature\Results\20 cm\final_result_table_20cm_with_wavelet.csv'
                                             ,index=False)
