# %% [markdown]
# # df_5_without wavelet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
df = pd.read_excel("Data/df_5.xlsx")

# %%
df.head()
# Out:
#    AvgAir_T_TempC  MaxAir_T_TempC  MinAir_T_TempC  Avg_Soil_TP05_TempC  \
# 0          -16.56          -14.47          -21.08                -3.05
# 1          -22.76          -15.73          -26.86                -3.43
# 2          -22.84          -17.48          -28.16                -4.12
# 3          -15.29          -12.80          -18.95                -3.99
# 4          -17.46          -13.48          -22.01                -3.46
#
#    Max_Soil_TP05_TempC  Min_Soil_TP05_TempC
# 0                -2.98                -3.11
# 1                -3.02                -3.76
# 2                -3.76                -4.28
# 3                -3.64                -4.28
# 4                -3.37                -3.64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3162 entries, 0 to 3161
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AvgAir_T_TempC       3162 non-null   float64
#  1   MaxAir_T_TempC       3162 non-null   float64
#  2   MinAir_T_TempC       3162 non-null   float64
#  3   Avg_Soil_TP05_TempC  3162 non-null   float64
#  4   Max_Soil_TP05_TempC  3162 non-null   float64
#  5   Min_Soil_TP05_TempC  3162 non-null   float64
# dtypes: float64(6)
# memory usage: 148.3 KB

# %% [markdown]
# # 1- Data Preprocesing

# %%
df["Avg_Soil_TP05_TempC_Plus_1"] = df["Avg_Soil_TP05_TempC"].shift(-1)
df["Avg_Soil_TP05_TempC_Plus_2"] = df["Avg_Soil_TP05_TempC"].shift(-2)

df["Max_Soil_TP05_TempC_Plus_1"] = df["Max_Soil_TP05_TempC"].shift(-1)
df["Max_Soil_TP05_TempC_Plus_2"] = df["Max_Soil_TP05_TempC"].shift(-2)

df["Min_Soil_TP05_TempC_Plus_1"] = df["Min_Soil_TP05_TempC"].shift(-1)
df["Min_Soil_TP05_TempC_Plus_2"] = df["Min_Soil_TP05_TempC"].shift(-2)

df["AvgAir_T_TempC_Minus_6"] = df["AvgAir_T_TempC"].shift(6)
df["AvgAir_T_TempC_Minus_5"] = df["AvgAir_T_TempC"].shift(5)
df["AvgAir_T_TempC_Minus_4"] = df["AvgAir_T_TempC"].shift(4)
df["AvgAir_T_TempC_Minus_3"] = df["AvgAir_T_TempC"].shift(3)
df["AvgAir_T_TempC_Minus_2"] = df["AvgAir_T_TempC"].shift(2)
df["AvgAir_T_TempC_Minus_1"] = df["AvgAir_T_TempC"].shift(1)

df["MaxAir_T_TempC_Minus_6"] = df["MaxAir_T_TempC"].shift(6)
df["MaxAir_T_TempC_Minus_5"] = df["MaxAir_T_TempC"].shift(5)
df["MaxAir_T_TempC_Minus_4"] = df["MaxAir_T_TempC"].shift(4)
df["MaxAir_T_TempC_Minus_3"] = df["MaxAir_T_TempC"].shift(3)
df["MaxAir_T_TempC_Minus_2"] = df["MaxAir_T_TempC"].shift(2)
df["MaxAir_T_TempC_Minus_1"] = df["MaxAir_T_TempC"].shift(1)


df["MinAir_T_TempC_Minus_6"] = df["MinAir_T_TempC"].shift(6)
df["MinAir_T_TempC_Minus_5"] = df["MinAir_T_TempC"].shift(5)
df["MinAir_T_TempC_Minus_4"] = df["MinAir_T_TempC"].shift(4)
df["MinAir_T_TempC_Minus_3"] = df["MinAir_T_TempC"].shift(3)
df["MinAir_T_TempC_Minus_2"] = df["MinAir_T_TempC"].shift(2)
df["MinAir_T_TempC_Minus_1"] = df["MinAir_T_TempC"].shift(1)

# %%
df = df[["AvgAir_T_TempC_Minus_6","MaxAir_T_TempC_Minus_6","MinAir_T_TempC_Minus_6",
          "AvgAir_T_TempC_Minus_5","MaxAir_T_TempC_Minus_5","MinAir_T_TempC_Minus_5",
          "AvgAir_T_TempC_Minus_4","MaxAir_T_TempC_Minus_4","MinAir_T_TempC_Minus_4",
          "AvgAir_T_TempC_Minus_3","MaxAir_T_TempC_Minus_3","MinAir_T_TempC_Minus_3",
          "AvgAir_T_TempC_Minus_2","MaxAir_T_TempC_Minus_2","MinAir_T_TempC_Minus_2",
          "AvgAir_T_TempC_Minus_1","MaxAir_T_TempC_Minus_1","MinAir_T_TempC_Minus_1",
          "AvgAir_T_TempC","MaxAir_T_TempC","MinAir_T_TempC",
          "Avg_Soil_TP05_TempC","Max_Soil_TP05_TempC","Min_Soil_TP05_TempC",
          "Avg_Soil_TP05_TempC_Plus_1","Max_Soil_TP05_TempC_Plus_1","Min_Soil_TP05_TempC_Plus_1",
          "Avg_Soil_TP05_TempC_Plus_2","Max_Soil_TP05_TempC_Plus_2","Min_Soil_TP05_TempC_Plus_2"]]
df.dropna(inplace=True)

# %%
df.reset_index(drop="True", inplace=True)

# %%
df.head().transpose()
# Out:
#                                 0      1      2      3      4
# AvgAir_T_TempC_Minus_6     -16.56 -22.76 -22.84 -15.29 -17.46
# MaxAir_T_TempC_Minus_6     -14.47 -15.73 -17.48 -12.80 -13.48
# MinAir_T_TempC_Minus_6     -21.08 -26.86 -28.16 -18.95 -22.01
# AvgAir_T_TempC_Minus_5     -22.76 -22.84 -15.29 -17.46 -20.40
# MaxAir_T_TempC_Minus_5     -15.73 -17.48 -12.80 -13.48 -14.98
# MinAir_T_TempC_Minus_5     -26.86 -28.16 -18.95 -22.01 -26.08
# AvgAir_T_TempC_Minus_4     -22.84 -15.29 -17.46 -20.40 -15.19
# MaxAir_T_TempC_Minus_4     -17.48 -12.80 -13.48 -14.98 -12.14
# MinAir_T_TempC_Minus_4     -28.16 -18.95 -22.01 -26.08 -19.12
# AvgAir_T_TempC_Minus_3     -15.29 -17.46 -20.40 -15.19 -15.93
# MaxAir_T_TempC_Minus_3     -12.80 -13.48 -14.98 -12.14 -11.16
# MinAir_T_TempC_Minus_3     -18.95 -22.01 -26.08 -19.12 -24.52
# AvgAir_T_TempC_Minus_2     -17.46 -20.40 -15.19 -15.93 -19.48
# MaxAir_T_TempC_Minus_2     -13.48 -14.98 -12.14 -11.16 -13.23
# MinAir_T_TempC_Minus_2     -22.01 -26.08 -19.12 -24.52 -25.86
# AvgAir_T_TempC_Minus_1     -20.40 -15.19 -15.93 -19.48 -14.68
# MaxAir_T_TempC_Minus_1     -14.98 -12.14 -11.16 -13.23 -10.11
# MinAir_T_TempC_Minus_1     -26.08 -19.12 -24.52 -25.86 -21.42
# AvgAir_T_TempC             -15.19 -15.93 -19.48 -14.68 -14.34
# MaxAir_T_TempC             -12.14 -11.16 -13.23 -10.11 -10.63
# MinAir_T_TempC             -19.12 -24.52 -25.86 -21.42 -17.79
# Avg_Soil_TP05_TempC         -3.77  -3.45  -3.87  -3.96  -3.52
# Max_Soil_TP05_TempC         -3.59  -3.36  -3.53  -3.64  -3.46
# Min_Soil_TP05_TempC         -3.83  -3.59  -3.98  -4.10  -3.64
# Avg_Soil_TP05_TempC_Plus_1  -3.45  -3.87  -3.96  -3.52  -3.52
# Max_Soil_TP05_TempC_Plus_1  -3.36  -3.53  -3.64  -3.46  -3.44
# Min_Soil_TP05_TempC_Plus_1  -3.59  -3.98  -4.10  -3.64  -3.56
# Avg_Soil_TP05_TempC_Plus_2  -3.87  -3.96  -3.52  -3.52  -3.33
# Max_Soil_TP05_TempC_Plus_2  -3.53  -3.64  -3.46  -3.44  -3.06
# Min_Soil_TP05_TempC_Plus_2  -3.98  -4.10  -3.64  -3.56  -3.44

# %% [markdown]
# # 2 - Feature Selection

# %%
#df --> Dataframe
#Ys --> a list of all target variables
#y --> the main target variable - string
def FeatureSelection(df,Ys,y,corr):
    X = df.drop(Ys,axis=1)
    Y = df[y]
    df_final = pd.concat([X,Y],axis=1)
    indexes = df_final.corr()[df_final.corr()[y] > corr].index
    df_final = df_final[indexes]
    return df_final

# %%
Ys = ["Avg_Soil_TP05_TempC", "Max_Soil_TP05_TempC", "Min_Soil_TP05_TempC","Avg_Soil_TP05_TempC_Plus_1",
     "Max_Soil_TP05_TempC_Plus_1","Min_Soil_TP05_TempC_Plus_1", "Avg_Soil_TP05_TempC_Plus_2", 
      "Max_Soil_TP05_TempC_Plus_2", "Min_Soil_TP05_TempC_Plus_2"]

# %%
df_avg = FeatureSelection(df,Ys,y = "Avg_Soil_TP05_TempC",corr=0.85)
df_max = FeatureSelection(df,Ys,y = "Max_Soil_TP05_TempC",corr=0.85)
df_min = FeatureSelection(df,Ys,y = "Min_Soil_TP05_TempC",corr=0.85)
df_avg_plus1 = FeatureSelection(df,Ys,y = "Avg_Soil_TP05_TempC_Plus_1",corr=0.85)
df_max_plus1 = FeatureSelection(df,Ys,y = "Max_Soil_TP05_TempC_Plus_1",corr=0.85)
df_min_plus1 = FeatureSelection(df,Ys,y = "Min_Soil_TP05_TempC_Plus_1",corr=0.85)
df_avg_plus2 = FeatureSelection(df,Ys,y = "Avg_Soil_TP05_TempC_Plus_2",corr=0.85)
df_max_plus2 = FeatureSelection(df,Ys,y = "Max_Soil_TP05_TempC_Plus_2",corr=0.85)
df_min_plus2 = FeatureSelection(df,Ys,y = "Min_Soil_TP05_TempC_Plus_2",corr=0.85)

# %% [markdown]
# # 3 - SVR Support vector machines for regression Problem

# %% [markdown]
# ### Train test split and data transform

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#df: data frame
#y: target variable --> string
def SplitTransform(df,y,test_size, scaler):
    X = df.drop(y,axis=1).values
    y = df[y].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=101)
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    data = [X_train, X_test,y_train,y_test]
    return data

# %% [markdown]
# ### Building the Model

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
model = SVR(gamma="auto")

# %%
param_grid = {"kernel" : ["rbf", "linear","poly"],
             "C" : [0.1,1,10,20,30,40]}
grid = GridSearchCV(model,param_grid, cv = 5)

# %% [markdown]
# ### Ftitting each target variable to the model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
Ys = {"Avg_Soil_TP05_TempC":df_avg, "Max_Soil_TP05_TempC":df_max, "Min_Soil_TP05_TempC":df_min,"Avg_Soil_TP05_TempC_Plus_1":df_avg_plus1,
     "Max_Soil_TP05_TempC_Plus_1":df_max_plus1,"Min_Soil_TP05_TempC_Plus_1":df_min_plus1, "Avg_Soil_TP05_TempC_Plus_2":df_avg_plus2, 
      "Max_Soil_TP05_TempC_Plus_2":df_max_plus2, "Min_Soil_TP05_TempC_Plus_2":df_min_plus2}

SVM_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    SVM_results.append(dictinary)

SVM_results
# Out:
# Avg_Soil_TP05_TempC
# Max_Soil_TP05_TempC
# Min_Soil_TP05_TempC
# Avg_Soil_TP05_TempC_Plus_1
# Max_Soil_TP05_TempC_Plus_1
# Min_Soil_TP05_TempC_Plus_1
# Avg_Soil_TP05_TempC_Plus_2
# Max_Soil_TP05_TempC_Plus_2
# Min_Soil_TP05_TempC_Plus_2
# [{'Target Variable': 'Avg_Soil_TP05_TempC',
#   'Best Parameters': {'C': 20, 'kernel': 'rbf'},
#   'R Squared': 0.9632781973315777,
#   'MAE': 1.3468031919275876,
#   'MSE': 3.270999614557363},
#  {'Target Variable': 'Max_Soil_TP05_TempC',
#   'Best Parameters': {'C': 10, 'kernel': 'rbf'},
#   'R Squared': 0.9669416351960253,
#   'MAE': 1.4410311877758126,
#   'MSE': 3.4763614624282115},
#  {'Target Variable': 'Min_Soil_TP05_TempC',
#   'Best Parameters': {'C': 20, 'kernel': 'rbf'},
#   'R Squared': 0.9456418901843813,
#   'MAE': 1.4553914163969828,
#   'MSE': 4.181228197319759},
#  {'Target Variable': 'Avg_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'C': 10, 'kernel': 'rbf'},
#   'R Squared': 0.9593645821864774,
#   'MAE': 1.4408094187251557,
#   'MSE': 3.6375865223362736},
#  {'Target Variable': 'Max_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'C': 10, 'kernel': 'rbf'},
#   'R Squared': 0.9575821559345538,
#   'MAE': 1.6310270911648241,
#   'MSE': 4.462707412224022},
#  {'Target Variable': 'Min_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'C': 20, 'kernel': 'rbf'},
#   'R Squared': 0.9406755499389011,
#   'MAE': 1.5183134235404048,
#   'MSE': 4.589079611852848},
#  {'Target Variable': 'Avg_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'C': 10, 'kernel': 'rbf'},
#   'R Squared': 0.9458283986018304,
#   'MAE': 1.6622771791424444,
#   'MSE': 4.827587821711122},
#  {'Target Variable': 'Max_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'C': 10, 'kernel': 'rbf'},
#   'R Squared': 0.9441990958282332,
#   'MAE': 1.8258718036182149,
#   'MSE': 5.841952485741098},
#  {'Target Variable': 'Min_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'C': 10, 'kernel': 'rbf'},
#   'R Squared': 0.9276476855718018,
#   'MAE': 1.7304082531499045,
#   'MSE': 5.578834341597246}]

# %% [markdown]
# # 4 - XGBoost (Extreme Gradient Boosting Method) for regression problem

# %% [markdown]
# ### BUilding the model

# %%
import xgboost as xg

# %%
model = xg.XGBRegressor(objective ='reg:squarederror')

# %%
param_grid = {
    'max_depth': [4, 5, 6, 7],
    'learning_rate': [0.5,0.1, 0.01, 0.05],
    'gamma': [0, 0.25, 1.0],
    'reg_lambda': [0, 1.0, 10.0],
    'n_estimators' : [15,20,50,100,150]
      }
grid = GridSearchCV(model,param_grid, cv = 5, verbose=3)

# %% [markdown]
# ### Ftitting each target variable to the model

# %%
Ys = {"Avg_Soil_TP05_TempC":df_avg, "Max_Soil_TP05_TempC":df_max, "Min_Soil_TP05_TempC":df_min,"Avg_Soil_TP05_TempC_Plus_1":df_avg_plus1,
     "Max_Soil_TP05_TempC_Plus_1":df_max_plus1,"Min_Soil_TP05_TempC_Plus_1":df_min_plus1, "Avg_Soil_TP05_TempC_Plus_2":df_avg_plus2, 
      "Max_Soil_TP05_TempC_Plus_2":df_max_plus2, "Min_Soil_TP05_TempC_Plus_2":df_min_plus2}

XGB_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    XGB_results.append(dictinary)

XGB_results
# Out:
# Avg_Soil_TP05_TempC
# Max_Soil_TP05_TempC
# Min_Soil_TP05_TempC
# Avg_Soil_TP05_TempC_Plus_1
# Max_Soil_TP05_TempC_Plus_1
# Min_Soil_TP05_TempC_Plus_1
# Avg_Soil_TP05_TempC_Plus_2
# Max_Soil_TP05_TempC_Plus_2
# Min_Soil_TP05_TempC_Plus_2
# [{'Target Variable': 'Avg_Soil_TP05_TempC',
#   'Best Parameters': {'gamma': 0.25,
#    'learning_rate': 0.05,
#    'max_depth': 4,
#    'n_estimators': 100,
#    'reg_lambda': 1.0},
#   'R Squared': 0.9626164492237009,
#   'MAE': 1.3738448041469773,
#   'MSE': 3.329944918123861},
#  {'Target Variable': 'Max_Soil_TP05_TempC',
#   'Best Parameters': {'gamma': 0.25,
#    'learning_rate': 0.05,
#    'max_depth': 4,
#    'n_estimators': 100,
#    'reg_lambda': 1.0},
#   'R Squared': 0.9660793166994834,
#   'MAE': 1.4626115942127222,
#   'MSE': 3.5670414100751295},
#  {'Target Variable': 'Min_Soil_TP05_TempC',
#   'Best Parameters': {'gamma': 1.0,
#    'learning_rate': 0.05,
#    'max_depth': 4,
#    'n_estimators': 100,
#    'reg_lambda': 1.0},
#   'R Squared': 0.9456029221217199,
#   'MAE': 1.495134454960556,
#   'MSE': 4.184225622413223},
#  {'Target Variable': 'Avg_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'gamma': 0,
#    'learning_rate': 0.05,
#    'max_depth': 4,
#    'n_estimators': 100,
#    'reg_lambda': 10.0},
#   'R Squared': 0.95736830928472,
#   'MAE': 1.4934636180013134,
#   'MSE': 3.816288152418224},
#  {'Target Variable': 'Max_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'gamma': 0,
#    'learning_rate': 0.1,
#    'max_depth': 4,
#    'n_estimators': 50,
#    'reg_lambda': 1.0},
#   'R Squared': 0.9554379626201327,
#   'MAE': 1.68386789625902,
#   'MSE': 4.688294252110189},
#  {'Target Variable': 'Min_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'gamma': 1.0,
#    'learning_rate': 0.05,
#    'max_depth': 4,
#    'n_estimators': 100,
#    'reg_lambda': 10.0},
#   'R Squared': 0.9401718447283653,
#   'MAE': 1.5754109788708852,
#   'MSE': 4.628044040678961},
#  {'Target Variable': 'Avg_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'gamma': 0.25,
#    'learning_rate': 0.05,
#    'max_depth': 4,
#    'n_estimators': 100,
#    'reg_lambda': 1.0},
#   'R Squared': 0.9432280883545053,
#   'MAE': 1.720005640696573,
#   'MSE': 5.059318576546834},
#  {'Target Variable': 'Max_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'gamma': 0,
#    'learning_rate': 0.1,
#    'max_depth': 4,
#    'n_estimators': 50,
#    'reg_lambda': 1.0},
#   'R Squared': 0.9414898101449289,
#   'MAE': 1.880445244347533,
#   'MSE': 6.1255951697994435},
#  {'Target Variable': 'Min_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'gamma': 1.0,
#    'learning_rate': 0.1,
#    'max_depth': 4,
#    'n_estimators': 50,
#    'reg_lambda': 1.0},
#   'R Squared': 0.9260323215703822,
#   'MAE': 1.795406148852869,
#   'MSE': 5.703389419572576}]

# %% [markdown]
# # 5 - ANN

# %% [markdown]
# ### Building the Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor

# %%
def create_model(neurons,hidden_layers, optimizer, activation):
    model = Sequential()
    
    # Add aninput layer
    model.add(Dense(X_train.shape[1], activation = activation))
    
    for i in range(hidden_layers):
    # Add one hidden layer
        model.add(Dense(neurons, activation=activation))
        
        
    # Add an output layer 
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer = optimizer, loss="mse")
    
    return model

# %%
model = KerasRegressor(build_fn=create_model, verbose = 3)

# %%
param_grid = {
    'batch_size': [128],
    'epochs': [200, 400],
    'neurons': [150, 250,350],
    'hidden_layers': [4,6,8],
    'optimizer' : ['Adam'],
    "activation" : ['relu',"sigmoid"]
      }
grid = GridSearchCV(model,param_grid,n_jobs=-1, cv = 5, verbose=3)

# %%
Ys = {"Avg_Soil_TP05_TempC":df_avg, "Max_Soil_TP05_TempC":df_max, "Min_Soil_TP05_TempC":df_min,"Avg_Soil_TP05_TempC_Plus_1":df_avg_plus1,
     "Max_Soil_TP05_TempC_Plus_1":df_max_plus1,"Min_Soil_TP05_TempC_Plus_1":df_min_plus1, "Avg_Soil_TP05_TempC_Plus_2":df_avg_plus2, 
      "Max_Soil_TP05_TempC_Plus_2":df_max_plus2, "Min_Soil_TP05_TempC_Plus_2":df_min_plus2}

ANN_results = []

for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_
400
# 18/18 [==============================] - 0s 4ms/step - loss: 5.2561
# Epoch 400/400
# 18/18 [==============================] - 0s 4ms/step - loss: 5.2231
# [{'Target Variable': 'Avg_Soil_TP05_TempC',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 6,
#    'neurons': 150,
#    'optimizer': 'Adam'},
#   'R Squared': 0.963746769179786,
#   'MAE': 1.4672874051118476,
#   'MSE': 3.489461729829694},
#  {'Target Variable': 'Max_Soil_TP05_TempC',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 4,
#    'neurons': 150,
#    'optimizer': 'Adam'},
#   'R Squared': 0.9678338483982338,
#   'MAE': 1.4809952495310856,
#   'MSE': 3.520932726900256},
#  {'Target Variable': 'Min_Soil_TP05_TempC',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 4,
#    'neurons': 350,
#    'optimizer': 'Adam'},
#   'R Squared': 0.9465197296393144,
#   'MAE': 1.5074517156192375,
#   'MSE': 4.15508310836362},
#  {'Target Variable': 'Avg_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 4,
#    'neurons': 250,
#    'optimizer': 'Adam'},
#   'R Squared': 0.9597388843783768,
#   'MAE': 1.4700036268973173,
#   'MSE': 3.712177185414891},
#  {'Target Variable': 'Max_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 4,
#    'neurons': 150,
#    'optimizer': 'Adam'},
#   'R Squared': 0.9574699027801679,
#   'MAE': 1.6526482022579645,
#   'MSE': 4.487655030298879},
#  {'Target Variable': 'Min_Soil_TP05_TempC_Plus_1',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 200,
#    'hidden_layers': 4,
#    'neurons': 150,
#    'optimizer': 'Adam'},
#   'R Squared': 0.9424662026711789,
#   'MAE': 1.5488183789973273,
#   'MSE': 4.460553975109917},
#  {'Target Variable': 'Avg_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 4,
#    'neurons': 350,
#    'optimizer': 'Adam'},
#   'R Squared': 0.944935770566116,
#   'MAE': 1.7178919546122031,
#   'MSE': 4.985146559043935},
#  {'Target Variable': 'Max_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 6,
#    'neurons': 150,
#    'optimizer': 'Adam'},
#   'R Squared': 0.9432279920523912,
#   'MAE': 1.8650459852320591,
#   'MSE': 5.970538812260912},
#  {'Target Variable': 'Min_Soil_TP05_TempC_Plus_2',
#   'Best Parameters': {'activation': 'sigmoid',
#    'batch_size': 128,
#    'epochs': 400,
#    'hidden_layers': 6,
#    'neurons': 150,
#    'optimizer': 'Adam'},
#   'R Squared': 0.9285547491894108,
#   'MAE': 1.7680283750472503,
#   'MSE': 5.601565497706258}]
