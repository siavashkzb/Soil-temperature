# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pywt

# %%
df = pd.read_excel("Data/df_50.xlsx")
df.head()
# Out:
#    AvgAir_T_TempC  MaxAir_T_TempC  MinAir_T_TempC  Avg_Soil_TP50_TempC  \
# 0           24.24           30.42            0.00                15.92
# 1           22.25           28.47           16.63                13.03
# 2           20.45           24.77           16.77                12.35
# 3           20.11           25.32           14.59                12.28
# 4           23.52           28.47           17.78                12.31
#
#    Max_Soil_TP50_TempC  Min_Soil_TP50_TempC
# 0                14.07                12.49
# 1                14.07                12.49
# 2                12.49                12.28
# 3                12.30                12.26
# 4                12.34                12.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AvgAir_T_TempC       433 non-null    float64
#  1   MaxAir_T_TempC       433 non-null    float64
#  2   MinAir_T_TempC       433 non-null    float64
#  3   Avg_Soil_TP50_TempC  433 non-null    float64
#  4   Max_Soil_TP50_TempC  433 non-null    float64
#  5   Min_Soil_TP50_TempC  433 non-null    float64
# dtypes: float64(6)
# memory usage: 20.4 KB

# %%
df["Avg_Soil_TP50_TempC_Plus_1"] = df["Avg_Soil_TP50_TempC"].shift(-1)
df["Avg_Soil_TP50_TempC_Plus_2"] = df["Avg_Soil_TP50_TempC"].shift(-2)

df["Max_Soil_TP50_TempC_Plus_1"] = df["Max_Soil_TP50_TempC"].shift(-1)
df["Max_Soil_TP50_TempC_Plus_2"] = df["Max_Soil_TP50_TempC"].shift(-2)

df["Min_Soil_TP50_TempC_Plus_1"] = df["Min_Soil_TP50_TempC"].shift(-1)
df["Min_Soil_TP50_TempC_Plus_2"] = df["Min_Soil_TP50_TempC"].shift(-2)

df["AvgAir_T_TempC_Minus_6"] = df["AvgAir_T_TempC"].shift(6)
df["AvgAir_T_TempC_Minus_5"] = df["AvgAir_T_TempC"].shift(5)
df["AvgAir_T_TempC_Minus_4"] = df["AvgAir_T_TempC"].shift(4)
df["AvgAir_T_TempC_Minus_3"] = df["AvgAir_T_TempC"].shift(3)
df["AvgAir_T_TempC_Minus_2"] = df["AvgAir_T_TempC"].shift(2)
df["AvgAir_T_TempC_Minus_1"] = df["AvgAir_T_TempC"].shift(1)

df["MaxAir_T_TempC_Minus_6"] = df["MaxAir_T_TempC"].shift(6)
df["MaxAir_T_TempC_Minus_5"] = df["MaxAir_T_TempC"].shift(5)
df["MaxAir_T_TempC_Minus_4"] = df["MaxAir_T_TempC"].shift(4)
df["MaxAir_T_TempC_Minus_3"] = df["MaxAir_T_TempC"].shift(3)
df["MaxAir_T_TempC_Minus_2"] = df["MaxAir_T_TempC"].shift(2)
df["MaxAir_T_TempC_Minus_1"] = df["MaxAir_T_TempC"].shift(1)


df["MinAir_T_TempC_Minus_6"] = df["MinAir_T_TempC"].shift(6)
df["MinAir_T_TempC_Minus_5"] = df["MinAir_T_TempC"].shift(5)
df["MinAir_T_TempC_Minus_4"] = df["MinAir_T_TempC"].shift(4)
df["MinAir_T_TempC_Minus_3"] = df["MinAir_T_TempC"].shift(3)
df["MinAir_T_TempC_Minus_2"] = df["MinAir_T_TempC"].shift(2)
df["MinAir_T_TempC_Minus_1"] = df["MinAir_T_TempC"].shift(1)

# %%
df = df[["AvgAir_T_TempC_Minus_6","MaxAir_T_TempC_Minus_6","MinAir_T_TempC_Minus_6",
          "AvgAir_T_TempC_Minus_5","MaxAir_T_TempC_Minus_5","MinAir_T_TempC_Minus_5",
          "AvgAir_T_TempC_Minus_4","MaxAir_T_TempC_Minus_4","MinAir_T_TempC_Minus_4",
          "AvgAir_T_TempC_Minus_3","MaxAir_T_TempC_Minus_3","MinAir_T_TempC_Minus_3",
          "AvgAir_T_TempC_Minus_2","MaxAir_T_TempC_Minus_2","MinAir_T_TempC_Minus_2",
          "AvgAir_T_TempC_Minus_1","MaxAir_T_TempC_Minus_1","MinAir_T_TempC_Minus_1",
          "AvgAir_T_TempC","MaxAir_T_TempC","MinAir_T_TempC",
          "Avg_Soil_TP50_TempC","Max_Soil_TP50_TempC","Min_Soil_TP50_TempC",
          "Avg_Soil_TP50_TempC_Plus_1","Max_Soil_TP50_TempC_Plus_1","Min_Soil_TP50_TempC_Plus_1",
          "Avg_Soil_TP50_TempC_Plus_2","Max_Soil_TP50_TempC_Plus_2","Min_Soil_TP50_TempC_Plus_2"]]
df.dropna(inplace=True)

# %%
df.reset_index(drop="True", inplace=True)
df
# Out:
#      AvgAir_T_TempC_Minus_6  MaxAir_T_TempC_Minus_6  MinAir_T_TempC_Minus_6  \
# 0                     24.24                   30.42                    0.00
# 1                     22.25                   28.47                   16.63
# 2                     20.45                   24.77                   16.77
# 3                     20.11                   25.32                   14.59
# 4                     23.52                   28.47                   17.78
# ..                      ...                     ...                     ...
# 420                   19.75                   29.30                    9.16
# 421                   18.19                   24.56                   10.54
# 422                   15.45                   24.52                    4.61
# 423                   19.27                   26.70                    9.93
# 424                   16.55                   21.89                   10.94
#
#      AvgAir_T_TempC_Minus_5  MaxAir_T_TempC_Minus_5  MinAir_T_TempC_Minus_5  \
# 0                     22.25                   28.47                   16.63
# 1                     20.45                   24.77                   16.77
# 2                     20.11                   25.32                   14.59
# 3                     23.52                   28.47                   17.78
# 4                     22.08                   27.30                   14.37
# ..                      ...                     ...                     ...
# 420                   18.19                   24.56                   10.54
# 421                   15.45                   24.52                    4.61
# 422                   19.27                   26.70                    9.93
# 423                   16.55                   21.89                   10.94
# 424                   14.50                   20.54                    6.70
#
#      AvgAir_T_TempC_Minus_4  MaxAir_T_TempC_Minus_4  MinAir_T_TempC_Minus_4  \
# 0                     20.45                   24.77                   16.77
# 1                     20.11                   25.32                   14.59
# 2                     23.52                   28.47                   17.78
# 3                     22.08                   27.30                   14.37
# 4                     21.49                   29.56                   11.12
# ..                      ...                     ...                     ...
# 420                   15.45                   24.52                    4.61
# 421                   19.27                   26.70                    9.93
# 422                   16.55                   21.89                   10.94
# 423                   14.50                   20.54                    6.70
# 424                   15.02                   23.63                    5.25
#
#      AvgAir_T_TempC_Minus_3  ...  MinAir_T_TempC  Avg_Soil_TP50_TempC  \
# 0                     20.11  ...           11.12                12.65
# 1                     23.52  ...           15.37                12.72
# 2                     22.08  ...           14.90                13.03
# 3                     21.49  ...           12.12                13.27
# 4                     21.90  ...           12.12                13.37
# ..                      ...  ...             ...                  ...
# 420                   19.27  ...            5.25                14.49
# 421                   16.55  ...            9.71                14.31
# 422                   14.50  ...           16.47                14.20
# 423                   15.02  ...           15.88                14.20
# 424                   18.12  ...           13.83                14.27
#
#      Max_Soil_TP50_TempC  Min_Soil_TP50_TempC  Avg_Soil_TP50_TempC_Plus_1  \
# 0                  12.77                12.53                       12.72
# 1                  13.03                12.52                       13.03
# 2                  13.20                12.81                       13.27
# 3                  13.33                13.18                       13.37
# 4                  13.40                13.32                       13.40
# ..                   ...                  ...                         ...
# 420                14.57                14.39                       14.31
# 421                14.39                14.24                       14.20
# 422                14.24                14.17                       14.20
# 423                14.25                14.16                       14.27
# 424                14.30                14.24                       14.31
#
#      Max_Soil_TP50_TempC_Plus_1  Min_Soil_TP50_TempC_Plus_1  \
# 0                         13.03                       12.52
# 1                         13.20                       12.81
# 2                         13.33                       13.18
# 3                         13.40                       13.32
# 4                         13.42                       13.38
# ..                          ...                         ...
# 420                       14.39                       14.24
# 421                       14.24                       14.17
# 422                       14.25                       14.16
# 423                       14.30                       14.24
# 424                       14.33                       14.28
#
#      Avg_Soil_TP50_TempC_Plus_2  Max_Soil_TP50_TempC_Plus_2  \
# 0                         13.03                       13.20
# 1                         13.27                       13.33
# 2                         13.37                       13.40
# 3                         13.40                       13.42
# 4                         13.43                       13.49
# ..                          ...                         ...
# 420                       14.20                       14.24
# 421                       14.20                       14.25
# 422                       14.27                       14.30
# 423                       14.31                       14.33
# 424                       14.27                       14.32
#
#      Min_Soil_TP50_TempC_Plus_2
# 0                         12.81
# 1                         13.18
# 2                         13.32
# 3                         13.38
# 4                         13.39
# ..                          ...
# 420                       14.17
# 421                       14.16
# 422                       14.24
# 423                       14.28
# 424                       14.18
#
# [425 rows x 30 columns]

# %%
def WaveletTransform(x,walvelettype,level):
    
    size = np.shape(x)
    length = (size[0] // (2**level)) * (2 ** level)
    x = x.iloc[0:length]
    bigmats = []
    for i in x.columns:
        vec = x[i].values
        cAs_cDs = pywt.swt(vec, wavelet=walvelettype, level=level,axis=0) 
        for j in cAs_cDs:
            bigmats.append(j[0])
            bigmats.append(j[1])

    
    features_num = len(bigmats)
    x = np.zeros((length, features_num))
    for i in range(0 ,len(bigmats)):
        for j in range(0,len(bigmats[0])):
            x[j,i] = x[j,i] + bigmats[i][j]
    
    return(x)

# %%
x = df.drop(["Avg_Soil_TP50_TempC","Max_Soil_TP50_TempC","Min_Soil_TP50_TempC",
            "Avg_Soil_TP50_TempC_Plus_1","Max_Soil_TP50_TempC_Plus_1","Min_Soil_TP50_TempC_Plus_1",
            "Avg_Soil_TP50_TempC_Plus_2","Max_Soil_TP50_TempC_Plus_2","Min_Soil_TP50_TempC_Plus_2"],axis=1)
df
# Out:
#      AvgAir_T_TempC_Minus_6  MaxAir_T_TempC_Minus_6  MinAir_T_TempC_Minus_6  \
# 0                     24.24                   30.42                    0.00
# 1                     22.25                   28.47                   16.63
# 2                     20.45                   24.77                   16.77
# 3                     20.11                   25.32                   14.59
# 4                     23.52                   28.47                   17.78
# ..                      ...                     ...                     ...
# 420                   19.75                   29.30                    9.16
# 421                   18.19                   24.56                   10.54
# 422                   15.45                   24.52                    4.61
# 423                   19.27                   26.70                    9.93
# 424                   16.55                   21.89                   10.94
#
#      AvgAir_T_TempC_Minus_5  MaxAir_T_TempC_Minus_5  MinAir_T_TempC_Minus_5  \
# 0                     22.25                   28.47                   16.63
# 1                     20.45                   24.77                   16.77
# 2                     20.11                   25.32                   14.59
# 3                     23.52                   28.47                   17.78
# 4                     22.08                   27.30                   14.37
# ..                      ...                     ...                     ...
# 420                   18.19                   24.56                   10.54
# 421                   15.45                   24.52                    4.61
# 422                   19.27                   26.70                    9.93
# 423                   16.55                   21.89                   10.94
# 424                   14.50                   20.54                    6.70
#
#      AvgAir_T_TempC_Minus_4  MaxAir_T_TempC_Minus_4  MinAir_T_TempC_Minus_4  \
# 0                     20.45                   24.77                   16.77
# 1                     20.11                   25.32                   14.59
# 2                     23.52                   28.47                   17.78
# 3                     22.08                   27.30                   14.37
# 4                     21.49                   29.56                   11.12
# ..                      ...                     ...                     ...
# 420                   15.45                   24.52                    4.61
# 421                   19.27                   26.70                    9.93
# 422                   16.55                   21.89                   10.94
# 423                   14.50                   20.54                    6.70
# 424                   15.02                   23.63                    5.25
#
#      AvgAir_T_TempC_Minus_3  ...  MinAir_T_TempC  Avg_Soil_TP50_TempC  \
# 0                     20.11  ...           11.12                12.65
# 1                     23.52  ...           15.37                12.72
# 2                     22.08  ...           14.90                13.03
# 3                     21.49  ...           12.12                13.27
# 4                     21.90  ...           12.12                13.37
# ..                      ...  ...             ...                  ...
# 420                   19.27  ...            5.25                14.49
# 421                   16.55  ...            9.71                14.31
# 422                   14.50  ...           16.47                14.20
# 423                   15.02  ...           15.88                14.20
# 424                   18.12  ...           13.83                14.27
#
#      Max_Soil_TP50_TempC  Min_Soil_TP50_TempC  Avg_Soil_TP50_TempC_Plus_1  \
# 0                  12.77                12.53                       12.72
# 1                  13.03                12.52                       13.03
# 2                  13.20                12.81                       13.27
# 3                  13.33                13.18                       13.37
# 4                  13.40                13.32                       13.40
# ..                   ...                  ...                         ...
# 420                14.57                14.39                       14.31
# 421                14.39                14.24                       14.20
# 422                14.24                14.17                       14.20
# 423                14.25                14.16                       14.27
# 424                14.30                14.24                       14.31
#
#      Max_Soil_TP50_TempC_Plus_1  Min_Soil_TP50_TempC_Plus_1  \
# 0                         13.03                       12.52
# 1                         13.20                       12.81
# 2                         13.33                       13.18
# 3                         13.40                       13.32
# 4                         13.42                       13.38
# ..                          ...                         ...
# 420                       14.39                       14.24
# 421                       14.24                       14.17
# 422                       14.25                       14.16
# 423                       14.30                       14.24
# 424                       14.33                       14.28
#
#      Avg_Soil_TP50_TempC_Plus_2  Max_Soil_TP50_TempC_Plus_2  \
# 0                         13.03                       13.20
# 1                         13.27                       13.33
# 2                         13.37                       13.40
# 3                         13.40                       13.42
# 4                         13.43                       13.49
# ..                          ...                         ...
# 420                       14.20                       14.24
# 421                       14.20                       14.25
# 422                       14.27                       14.30
# 423                       14.31                       14.33
# 424                       14.27                       14.32
#
#      Min_Soil_TP50_TempC_Plus_2
# 0                         12.81
# 1                         13.18
# 2                         13.32
# 3                         13.38
# 4                         13.39
# ..                          ...
# 420                       14.17
# 421                       14.16
# 422                       14.24
# 423                       14.28
# 424                       14.18
#
# [425 rows x 30 columns]

# %%
y = df[["Avg_Soil_TP50_TempC","Max_Soil_TP50_TempC","Min_Soil_TP50_TempC",
            "Avg_Soil_TP50_TempC_Plus_1","Max_Soil_TP50_TempC_Plus_1","Min_Soil_TP50_TempC_Plus_1",
            "Avg_Soil_TP50_TempC_Plus_2","Max_Soil_TP50_TempC_Plus_2","Min_Soil_TP50_TempC_Plus_2"]].values

# %%
x = WaveletTransform(x,"db5",5)

# %%
x.shape
# Out:
# (416, 210)

# %%
y = df[0:x.shape[0]]

# %%
x = pd.DataFrame(x)

# %%
df = pd.concat([x,y],axis=1)

# %%
df
# Out:
#              0         1          2         3          4         5          6  \
# 0    63.788969 -2.934640  81.092130  0.699315  54.865099 -4.801267  46.136754
# 1    65.274606 -4.381344  81.312692  2.015804  55.739448 -5.276362  42.107493
# 2    66.787133 -5.580971  81.369152  3.158354  57.132431 -4.032281  37.995890
# 3    68.318966 -6.573750  81.301376  3.775352  58.577150 -2.020705  35.516697
# 4    69.863607 -7.439896  81.153640  3.698452  59.803503  0.418576  34.832882
# ..         ...       ...        ...       ...        ...       ...        ...
# 411  56.139065  4.532026  78.420099 -2.731537  55.563476  3.619056  38.098491
# 412  57.739675  3.264100  79.060169 -2.864572  54.922004  2.698650  41.865780
# 413  59.298596  1.813591  79.677525 -2.274863  54.424450  1.157306  46.086753
# 414  60.814507  0.257546  80.231815 -1.368339  54.232844 -0.960877  48.590673
# 415  62.309464 -1.350784  80.712300 -0.421948  54.427416 -2.987529  48.413820
#
#             7          8         9  ...  MinAir_T_TempC  Avg_Soil_TP50_TempC  \
# 0    0.933353  23.939074  2.294474  ...           11.12                12.65
# 1    1.293356  25.742177 -1.822694  ...           15.37                12.72
# 2    0.213967  30.462259 -0.640552  ...           14.90                13.03
# 3   -2.364010  32.229497  1.145901  ...           12.12                13.27
# 4   -1.677906  29.836496 -0.260397  ...           12.12                13.37
# ..        ...        ...       ...  ...             ...                  ...
# 411  2.361043  32.114807 -1.926774  ...           10.62                15.37
# 412 -3.203784  29.541111  3.124138  ...            6.37                15.23
# 413 -4.512755  26.527360 -1.981640  ...           13.19                15.06
# 414 -0.748511  24.454810 -1.022841  ...            9.16                14.93
# 415  1.140895  24.209595  0.639380  ...           10.54                14.90
#
#      Max_Soil_TP50_TempC  Min_Soil_TP50_TempC  Avg_Soil_TP50_TempC_Plus_1  \
# 0                  12.77                12.53                       12.72
# 1                  13.03                12.52                       13.03
# 2                  13.20                12.81                       13.27
# 3                  13.33                13.18                       13.37
# 4                  13.40                13.32                       13.40
# ..                   ...                  ...                         ...
# 411                15.43                15.30                       15.23
# 412                15.30                15.16                       15.06
# 413                15.17                14.98                       14.93
# 414                14.98                14.90                       14.90
# 415                14.92                14.89                       14.91
#
#      Max_Soil_TP50_TempC_Plus_1  Min_Soil_TP50_TempC_Plus_1  \
# 0                         13.03                       12.52
# 1                         13.20                       12.81
# 2                         13.33                       13.18
# 3                         13.40                       13.32
# 4                         13.42                       13.38
# ..                          ...                         ...
# 411                       15.30                       15.16
# 412                       15.17                       14.98
# 413                       14.98                       14.90
# 414                       14.92                       14.89
# 415                       14.93                       14.87
#
#      Avg_Soil_TP50_TempC_Plus_2  Max_Soil_TP50_TempC_Plus_2  \
# 0                         13.03                       13.20
# 1                         13.27                       13.33
# 2                         13.37                       13.40
# 3                         13.40                       13.42
# 4                         13.43                       13.49
# ..                          ...                         ...
# 411                       15.06                       15.17
# 412                       14.93                       14.98
# 413                       14.90                       14.92
# 414                       14.91                       14.93
# 415                       14.79                       14.87
#
#      Min_Soil_TP50_TempC_Plus_2
# 0                         12.81
# 1                         13.18
# 2                         13.32
# 3                         13.38
# 4                         13.39
# ..                          ...
# 411                       14.98
# 412                       14.90
# 413                       14.89
# 414                       14.87
# 415                       14.71
#
# [416 rows x 240 columns]

# %% [markdown]
# # 2 - Feature Selection

# %%
# df --> Dataframe
#Ys --> a list of all target variables
#y --> the main target variable - string
def FeatureSelection(df,Ys,y,corr):
    X = df.drop(Ys,axis=1)
    Y = df[y]
    df_final = pd.concat([X,Y],axis=1)
    indexes = df_final.corr()[df_final.corr()[y] > corr].index
    df_final = df_final[indexes]
    return df_final

# %%
Ys = ["Avg_Soil_TP50_TempC", "Max_Soil_TP50_TempC", "Min_Soil_TP50_TempC","Avg_Soil_TP50_TempC_Plus_1",
     "Max_Soil_TP50_TempC_Plus_1","Min_Soil_TP50_TempC_Plus_1", "Avg_Soil_TP50_TempC_Plus_2", 
      "Max_Soil_TP50_TempC_Plus_2", "Min_Soil_TP50_TempC_Plus_2"]

# %%
df_avg = FeatureSelection(df,Ys,y = "Avg_Soil_TP50_TempC",corr=0.50)
df_max = FeatureSelection(df,Ys,y = "Max_Soil_TP50_TempC",corr=0.50)
df_min = FeatureSelection(df,Ys,y = "Min_Soil_TP50_TempC",corr=0.50)
df_avg_plus1 = FeatureSelection(df,Ys,y = "Avg_Soil_TP50_TempC_Plus_1",corr=0.50)
df_max_plus1 = FeatureSelection(df,Ys,y = "Max_Soil_TP50_TempC_Plus_1",corr=0.50)
df_min_plus1 = FeatureSelection(df,Ys,y = "Min_Soil_TP50_TempC_Plus_1",corr=0.50)
df_avg_plus2 = FeatureSelection(df,Ys,y = "Avg_Soil_TP50_TempC_Plus_2",corr=0.50)
df_max_plus2 = FeatureSelection(df,Ys,y = "Max_Soil_TP50_TempC_Plus_2",corr=0.50)
df_min_plus2 = FeatureSelection(df,Ys,y = "Min_Soil_TP50_TempC_Plus_2",corr=0.50)

# %%
final_result_table_50cm_with_wavelet = pd.DataFrame(columns=["output_variable", "MLAlgo", "real_value", 
                                                               "predicted_value", "mse_list", "mae_list", "r_sqaured"])
final_result_table_50cm_with_wavelet
# Out:
# Empty DataFrame
# Columns: [output_variable, MLAlgo, real_value, predicted_value, mse_list, mae_list, r_sqaured]
# Index: []

# %% [markdown]
# # 3 - SVR Support vector machines for regression Problem

# %% [markdown]
# ### Train test split and data transform

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#df: data frame
#y: target variable --> string
def SplitTransform(df,y,test_size, scaler):
    X = df.drop(y,axis=1).values
    y = df[y].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=101)
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    data = [X_train, X_test,y_train,y_test]
    return data

# %% [markdown]
# ### Building the Model

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
model = SVR(gamma="auto")

# %%
param_grid = {"kernel" : ["rbf"],
             "C" : [20]}
grid = GridSearchCV(model,param_grid, cv = 5)

# %%
Ys = {"Avg_Soil_TP50_TempC":df_avg, "Max_Soil_TP50_TempC":df_max, "Min_Soil_TP50_TempC":df_min,"Avg_Soil_TP50_TempC_Plus_1":df_avg_plus1,
     "Max_Soil_TP50_TempC_Plus_1":df_max_plus1,"Min_Soil_TP50_TempC_Plus_1":df_min_plus1, "Avg_Soil_TP50_TempC_Plus_2":df_avg_plus2, 
      "Max_Soil_TP50_TempC_Plus_2":df_max_plus2, "Min_Soil_TP50_TempC_Plus_2":df_min_plus2}

# %%
SVM_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    SVM_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["WSVM" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_50cm_with_wavelet = pd.concat([final_result_table_50cm_with_wavelet,result])
# Out:
# Avg_Soil_TP50_TempC
# Max_Soil_TP50_TempC
# Min_Soil_TP50_TempC
# Avg_Soil_TP50_TempC_Plus_1
# Max_Soil_TP50_TempC_Plus_1
# Min_Soil_TP50_TempC_Plus_1
# Avg_Soil_TP50_TempC_Plus_2
# Max_Soil_TP50_TempC_Plus_2
# Min_Soil_TP50_TempC_Plus_2

# %%
final_result_table_50cm_with_wavelet
# Out:
#                 output_variable MLAlgo  real_value  predicted_value  mse_list  \
# 0           Avg_Soil_TP50_TempC   WSVM       9.190         9.174161  0.077621
# 1           Avg_Soil_TP50_TempC   WSVM       4.687         4.807826  0.077621
# 2           Avg_Soil_TP50_TempC   WSVM      14.150        14.092495  0.077621
# 3           Avg_Soil_TP50_TempC   WSVM       0.252         0.327096  0.077621
# 4           Avg_Soil_TP50_TempC   WSVM       4.953         5.048572  0.077621
# ..                          ...    ...         ...              ...       ...
# 120  Min_Soil_TP50_TempC_Plus_2   WSVM      11.480        11.609555  0.051362
# 121  Min_Soil_TP50_TempC_Plus_2   WSVM      15.580        15.467379  0.051362
# 122  Min_Soil_TP50_TempC_Plus_2   WSVM      15.660        15.529806  0.051362
# 123  Min_Soil_TP50_TempC_Plus_2   WSVM      15.530        15.328814  0.051362
# 124  Min_Soil_TP50_TempC_Plus_2   WSVM      15.470        15.368501  0.051362
#
#      mae_list  r_sqaured
# 0    0.148535   0.997963
# 1    0.148535   0.997963
# 2    0.148535   0.997963
# 3    0.148535   0.997963
# 4    0.148535   0.997963
# ..        ...        ...
# 120  0.129340   0.998671
# 121  0.129340   0.998671
# 122  0.129340   0.998671
# 123  0.129340   0.998671
# 124  0.129340   0.998671
#
# [1125 rows x 7 columns]

# %% [markdown]
# # 4 - XGBoost (Extreme Gradient Boosting Method) for regression problem

# %% [markdown]
# ### Building the model

# %%
import xgboost as xg

# %%
model = xg.XGBRegressor(objective ='reg:squarederror')

# %%
param_grid = {
    'max_depth': [7],
    'learning_rate': [0.05],
    'gamma': [0],
    'reg_lambda': [1.0],
    'n_estimators' : [150]
      }
grid = GridSearchCV(model,param_grid, cv = 5, verbose=3)

# %%
XGBoost_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    XGBoost_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["WXGBoost" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_50cm_with_wavelet = pd.concat([final_result_table_50cm_with_wavelet,result])
# Out:
# Avg_Soil_TP50_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.4s finished
# Max_Soil_TP50_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.6s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.0s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.993, total=   0.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.5s finished
# Min_Soil_TP50_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.995, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.3s finished
# Avg_Soil_TP50_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.998, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.993, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.998, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.993, total=   0.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.3s finished
# Max_Soil_TP50_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.993, total=   0.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.3s finished
# Min_Soil_TP50_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.4s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.3s finished
# Avg_Soil_TP50_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.998, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.9s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.993, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.992, total=   0.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.2s finished
# Max_Soil_TP50_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.998, total=   0.6s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.6s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.1s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.994, total=   0.5s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.997, total=   0.6s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.991, total=   0.6s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.9s finished
# Min_Soil_TP50_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.998, total=   0.9s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.996, total=   0.7s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.5s remaining:    0.0s
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.993, total=   0.7s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.998, total=   0.6s
# [CV] gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0
# [CV]  gamma=0, learning_rate=0.05, max_depth=7, n_estimators=150, reg_lambda=1.0, score=0.991, total=   0.7s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.6s finished

# %%
final_result_table_50cm_with_wavelet
# Out:
#                 output_variable    MLAlgo  real_value  predicted_value  \
# 0           Avg_Soil_TP50_TempC      WSVM       9.190         9.174161
# 1           Avg_Soil_TP50_TempC      WSVM       4.687         4.807826
# 2           Avg_Soil_TP50_TempC      WSVM      14.150        14.092495
# 3           Avg_Soil_TP50_TempC      WSVM       0.252         0.327096
# 4           Avg_Soil_TP50_TempC      WSVM       4.953         5.048572
# ..                          ...       ...         ...              ...
# 120  Min_Soil_TP50_TempC_Plus_2  WXGBoost      11.480        12.457126
# 121  Min_Soil_TP50_TempC_Plus_2  WXGBoost      15.580        14.928654
# 122  Min_Soil_TP50_TempC_Plus_2  WXGBoost      15.660        15.504337
# 123  Min_Soil_TP50_TempC_Plus_2  WXGBoost      15.530        15.440570
# 124  Min_Soil_TP50_TempC_Plus_2  WXGBoost      15.470        15.417088
#
#      mse_list  mae_list  r_sqaured
# 0    0.077621  0.148535   0.997963
# 1    0.077621  0.148535   0.997963
# 2    0.077621  0.148535   0.997963
# 3    0.077621  0.148535   0.997963
# 4    0.077621  0.148535   0.997963
# ..        ...       ...        ...
# 120  0.092086  0.207008   0.997617
# 121  0.092086  0.207008   0.997617
# 122  0.092086  0.207008   0.997617
# 123  0.092086  0.207008   0.997617
# 124  0.092086  0.207008   0.997617
#
# [2250 rows x 7 columns]

# %% [markdown]
# # 5 - ANN

# %%
### Building the Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor

# %%
def create_model(neurons,hidden_layers, optimizer, activation):
    model = Sequential()
    
    # Add aninput layer
    model.add(Dense(X_train.shape[1], activation = activation))
    
    for i in range(hidden_layers):
    # Add one hidden layer
        model.add(Dense(neurons, activation=activation))
        
        
    # Add an output layer 
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer = optimizer, loss="mse")
    
    return model

# %%
model = KerasRegressor(build_fn=create_model, verbose = 3)

# %%
param_grid = {
    'batch_size': [128],
    'epochs': [400],
    'neurons': [150],
    'hidden_layers': [4],
    'optimizer' : ['Adam'],
    "activation" : ["relu"]
      }
grid = GridSearchCV(model,param_grid,n_jobs=-1, verbose=3)

# %%
ANN_results = []
for i in (Ys):
    print(i)
    X_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[0]
    X_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[1]
    y_train = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[2]
    y_test = SplitTransform(df = Ys[i], y = i, test_size= 0.3, scaler = StandardScaler())[3]
    grid.fit(X_train, y_train)
    best_params = grid.best_params_
    score = grid.score(X_test,y_test)
    prediction = grid.predict(X_test)
    MSE = mean_squared_error(y_test,prediction)
    MAE = mean_absolute_error(y_test,prediction) 
    dictinary = {"Target Variable" : i, "Best Parameters" : best_params, "R Squared" : score, "MAE": MAE,
                "MSE": MSE}
    ANN_results.append(dictinary)
    
    length = len(prediction)
    output_variable =  [i for j in range(length)]
    MLAlgo = ["WANN" for j in range(length)]
    mse_list = [MSE for j in range(length)]
    mae_list = [MAE for j in range(length)]
    r_squared = [score for j in range(length)]
    predicted_value = prediction.tolist()
    real_value = y_test.tolist()
    result = pd.DataFrame(list(zip(output_variable,MLAlgo,real_value,predicted_value,mse_list,mae_list,r_squared)),
                         columns=["output_variable", "MLAlgo", "real_value","predicted_value", "mse_list", "mae_list", "r_sqaured"])
    final_result_table_50cm_with_wavelet = pd.concat([final_result_table_50cm_with_wavelet,result])
# Out:
# Avg_Soil_TP50_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   19.9s remaining:   29.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   23.4s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Max_Soil_TP50_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.3s remaining:   14.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.8s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Min_Soil_TP50_TempC
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.2s remaining:   13.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.6s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Avg_Soil_TP50_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.6s remaining:   14.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   13.0s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Max_Soil_TP50_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.6s remaining:   14.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.1s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x000002EF68D15040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002EF68DD7160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Min_Soil_TP50_TempC_Plus_1
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.3s remaining:   14.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.9s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x000002EF6459B430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002EF64C98280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Avg_Soil_TP50_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.0s remaining:   13.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.8s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x000002EF65DEA430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002EF66507C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Max_Soil_TP50_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.0s remaining:   13.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   13.2s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_test_function.<locals>.test_function at 0x000002EF68D159D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002EF679DD700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Min_Soil_TP50_TempC_Plus_2
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.4s remaining:   14.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   13.2s finished
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x000002EF6788C670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002EF665070D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
final_result_table_50cm_with_wavelet.reset_index(drop = True)
# Out:
#                  output_variable MLAlgo  real_value  predicted_value  \
# 0            Avg_Soil_TP50_TempC   WSVM       9.190         9.174161
# 1            Avg_Soil_TP50_TempC   WSVM       4.687         4.807826
# 2            Avg_Soil_TP50_TempC   WSVM      14.150        14.092495
# 3            Avg_Soil_TP50_TempC   WSVM       0.252         0.327096
# 4            Avg_Soil_TP50_TempC   WSVM       4.953         5.048572
# ...                          ...    ...         ...              ...
# 3370  Min_Soil_TP50_TempC_Plus_2   WANN      11.480        11.652159
# 3371  Min_Soil_TP50_TempC_Plus_2   WANN      15.580        15.165387
# 3372  Min_Soil_TP50_TempC_Plus_2   WANN      15.660        15.350345
# 3373  Min_Soil_TP50_TempC_Plus_2   WANN      15.530        15.422519
# 3374  Min_Soil_TP50_TempC_Plus_2   WANN      15.470        15.216083
#
#       mse_list  mae_list  r_sqaured
# 0     0.077621  0.148535   0.997963
# 1     0.077621  0.148535   0.997963
# 2     0.077621  0.148535   0.997963
# 3     0.077621  0.148535   0.997963
# 4     0.077621  0.148535   0.997963
# ...        ...       ...        ...
# 3370  0.031257  0.117346  -0.031257
# 3371  0.031257  0.117346  -0.031257
# 3372  0.031257  0.117346  -0.031257
# 3373  0.031257  0.117346  -0.031257
# 3374  0.031257  0.117346  -0.031257
#
# [3375 rows x 7 columns]

# %%
final_result_table_50cm_with_wavelet.to_csv(r'C:\Users\siava\OneDrive - University of Manitoba\D\Computer science\Data Science Projects\Soil-temperature\Results\50 cm\final_result_table_50cm_with_wavelet.csv'
                                             ,index=False)
